# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime

# %%
df_input = pd.read_excel('Datasets/Cosmos_Dataset.xlsx')

# %%
df_tech = pd.read_excel('Datasets/Tech v Other related.xlsx', sheet_name = 'YES, I am Technology (n=495)')
df_tech = df_tech[['Concept', 'Tech Family']]
df_tech['Flag'] = 'Yes'
df_not_tech = pd.read_excel('Datasets/Tech v Other related.xlsx', sheet_name = 'Not TECHNOLOGY (n=168)')
df_not_tech = df_not_tech[df_not_tech['Unnamed: 2'] == 0]
df_not_tech = df_not_tech[['Concept', 'Unnamed: 4']]
df_not_tech.columns = ['Concept', 'Tech Family']
df_not_tech['Flag'] = 'No'
tech_list = ['Precision agriculture', 'Computer-aided design', 'Energy management system']
df_not_tech = df_not_tech[~df_not_tech['Concept'].isin(tech_list)]
df_tech = df_tech[~df_tech['Concept'].isin(df_not_tech['Concept'])]
df_tech = df_tech.sort_values('Tech Family')

# %%
df_input['ET7 theme clusters'].value_counts()
# Out:
# Networking & Connectivity    4232
# Biotechnology                4159
# Data & Analytics             4076
# Autonomous Systems           3642
# Health & Medical             2952
# Converging Technology        2382
# Nanotechnology               2101
# Name: ET7 theme clusters, dtype: int64

# %%
# Autonomous Systems
# GS_Author_Counts > 0
check_tech_list1 = df_input[(df_input['ET7 theme clusters'] == 'Autonomous Systems') & (df_input['GS_Author_Counts'] > 0) & (~df_input['Wiki_Entity'].isin(autonomous_tech_list))]['Wiki_Entity'].tolist()
len(check_tech_list1)

# ET100
check_tech_list2 = df_input[(df_input['ET7 theme clusters'] == 'Autonomous Systems') & (df_input['ET100_Flag'] == 'Yes') & (~df_input['Wiki_Entity'].isin(check_tech_list)) & (~df_input['Wiki_Entity'].isin(autonomous_tech_list1))]['Wiki_Entity'].tolist()
len(check_tech_list2)

# TFR > 0
check_tech_list3 = df_input[(df_input['ET7 theme clusters'] == 'Autonomous Systems') & (df_input['TFR'] > 0) & (df_input['ET100_Flag'] == 'No') & (~df_input['Wiki_Entity'].isin(check_tech_list)) & (~df_input['Wiki_Entity'].isin(autonomous_tech_list))]['Wiki_Entity'].tolist()
len(check_tech_list3)

# Biotechnology
# ET100
bio_check_tech_list1 = df_input[(df_input['ET7 theme clusters'] == 'Biotechnology') & (df_input['ET100_Flag'] == 'Yes')]['Wiki_Entity'].tolist()
len(bio_check_tech_list1)

# Paul checked
bio_check_tech_list2 = df_tech[df_tech['Tech Family'] == 'Biotechnologies']['Concept'].tolist()
len(bio_check_tech_list2)

# GS_Author_Counts > 0
bio_check_tech_list3 = df_input[(df_input['ET7 theme clusters'] == 'Biotechnology') & (df_input['GS_Author_Counts'] > 0) & (~df_input['Wiki_Entity'].isin(bio_check_tech_list1)) & (~df_input['Wiki_Entity'].isin(bio_check_tech_list2))]['Wiki_Entity'].tolist()
len(bio_check_tech_list3)

# Converging Technology
# ET100
conv_check_tech_list1 = df_input[(df_input['ET7 theme clusters'] == 'Converging Technology') & (df_input['ET100_Flag'] == 'Yes')]['Wiki_Entity'].tolist()
len(conv_check_tech_list1)

# Paul checked
conv_check_tech_list2 = df_tech[df_tech['Tech Family'] == 'ConvergeTech']['Concept'].tolist()
len(conv_check_tech_list2)

# GS_Author_Counts > 0
conv_check_tech_list3 = df_input[(df_input['ET7 theme clusters'] == 'Converging Technology') & (df_input['GS_Author_Counts'] > 0) & (~df_input['Wiki_Entity'].isin(conv_check_tech_list1)) & (~df_input['Wiki_Entity'].isin(conv_check_tech_list2))]['Wiki_Entity'].tolist()
len(conv_check_tech_list3)

# Publication_Counts_5yr_slope > 0
conv_check_tech_list4 = df_input[(df_input['ET7 theme clusters'] == 'Converging Technology') & (df_input['Publication_Counts_5yr_slope'] > 0) & (~df_input['ET100_Flag'].isin(conv_check_tech_list1)) & (~df_input['Wiki_Entity'].isin(conv_check_tech_list2)) & (~df_input['Wiki_Entity'].isin(conv_check_tech_list3))]['Wiki_Entity'].tolist()
len(conv_check_tech_list4)

# Data & Analytics
# ET100
data_check_tech_list1 = df_input[(df_input['ET7 theme clusters'] == 'Data & Analytics') & (df_input['ET100_Flag'] == 'Yes')]['Wiki_Entity'].tolist()
len(data_check_tech_list1)

# Paul checked
data_check_tech_list2 = df_tech[df_tech['Tech Family'] == 'Data technologies']['Concept'].tolist()
len(data_check_tech_list2)

# GS_Author_Counts > 0
data_check_tech_list3 = df_input[(df_input['ET7 theme clusters'] == 'Data & Analytics') & (df_input['GS_Author_Counts'] > 0) & (~df_input['Wiki_Entity'].isin(data_check_tech_list1)) & (~df_input['Wiki_Entity'].isin(data_check_tech_list2))]['Wiki_Entity'].tolist()
len(data_check_tech_list3)

# Publication_Counts_5yr_slope > 0
data_check_tech_list4 = df_input[(df_input['ET7 theme clusters'] == 'Data & Analytics') & (df_input['Publication_Counts_5yr_slope'] > 0) & (~df_input['ET100_Flag'].isin(data_check_tech_list1)) & (~df_input['Wiki_Entity'].isin(data_check_tech_list2)) & (~df_input['Wiki_Entity'].isin(data_check_tech_list3))]['Wiki_Entity'].tolist()
len(data_check_tech_list4)

# Pageviews_5yr_slope > 0
data_check_tech_list5 = df_input[(df_input['ET7 theme clusters'] == 'Data & Analytics') & (df_input['Pageviews_5yr_slope'] > 0) & (~df_input['ET100_Flag'].isin(data_check_tech_list1)) & (~df_input['Wiki_Entity'].isin(data_check_tech_list2)) & (~df_input['Wiki_Entity'].isin(data_check_tech_list3)) & (~df_input['Wiki_Entity'].isin(data_check_tech_list4))]['Wiki_Entity'].tolist()
len(data_check_tech_list5)

# Health & Medical
# sorted by cosine_dist_to_anchor
health_check_tech_list6 = df_input[(df_input['ET7 theme clusters'] == 'Health & Medical')].sort_values('cosine_dist_to_anchor')['Wiki_Entity'].tolist()
len(health_check_tech_list6)

# Networking & Connectivity
# ET100
network_check_tech_list1 = df_input[(df_input['ET7 theme clusters'] == 'Networking & Connectivity') & (df_input['ET100_Flag'] == 'Yes')]['Wiki_Entity'].tolist()
len(health_check_tech_list1)

# Paul checked
network_check_tech_list2 = df_tech[df_tech['Tech Family'] == 'Network technologies']['Concept'].tolist()
len(network_check_tech_list2)

# GS_Author_Counts > 0
network_check_tech_list3 = df_input[(df_input['ET7 theme clusters'] == 'Networking & Connectivity') & (df_input['GS_Author_Counts'] > 0) & (~df_input['Wiki_Entity'].isin(network_check_tech_list1)) & (~df_input['Wiki_Entity'].isin(network_check_tech_list2))]['Wiki_Entity'].tolist()
len(network_check_tech_list3)

# Publication_Counts_5yr_slope > 0
network_check_tech_list4 = df_input[(df_input['ET7 theme clusters'] == 'Networking & Connectivity') & (df_input['Publication_Counts_5yr_slope'] > 0) & (~df_input['ET100_Flag'].isin(network_check_tech_list1)) & (~df_input['Wiki_Entity'].isin(network_check_tech_list2)) & (~df_input['Wiki_Entity'].isin(network_check_tech_list3))]['Wiki_Entity'].tolist()
len(network_check_tech_list4)

# Pageviews_5yr_slope > 0
network_check_tech_list5 = df_input[(df_input['ET7 theme clusters'] == 'Networking & Connectivity') & (~df_input['ET100_Flag'].isin(network_check_tech_list1)) & (~df_input['Wiki_Entity'].isin(network_check_tech_list2)) & (~df_input['Wiki_Entity'].isin(network_check_tech_list3)) & (~df_input['Wiki_Entity'].isin(network_check_tech_list4))].sort_values('cosine_dist_to_anchor')['Wiki_Entity'].tolist()
len(network_check_tech_list5)

# sorted by cosine_dist_to_anchor
network_check_tech_list6 = df_input[(df_input['ET7 theme clusters'] == 'Networking & Connectivity')].sort_values('cosine_dist_to_anchor')['Wiki_Entity'].tolist()
len(network_check_tech_list6)

# Nanotechnology
# ET100
nanotech_check_tech_list1 = df_input[(df_input['ET7 theme clusters'] == 'Nanotechnology') & (df_input['ET100_Flag'] == 'Yes')]['Wiki_Entity'].tolist()
len(nanotech_check_tech_list1)

# Paul checked
nanotech_check_tech_list2 = df_tech[df_tech['Tech Family'] == 'Nanotech']['Concept'].tolist()
len(nanotech_check_tech_list2)

# GS_Author_Counts > 0
nanotech_check_tech_list3 = df_input[(df_input['ET7 theme clusters'] == 'Nanotechnology') & (df_input['GS_Author_Counts'] > 0) & (~df_input['Wiki_Entity'].isin(nanotech_check_tech_list1)) & (~df_input['Wiki_Entity'].isin(nanotech_check_tech_list2))]['Wiki_Entity'].tolist()
len(nanotech_check_tech_list3)

# Publication_Counts_5yr_slope > 0
nanotech_check_tech_list4 = df_input[(df_input['ET7 theme clusters'] == 'Nanotechnology') & (df_input['Publication_Counts_5yr_slope'] > 0) & (~df_input['ET100_Flag'].isin(nanotech_check_tech_list1)) & (~df_input['Wiki_Entity'].isin(nanotech_check_tech_list2)) & (~df_input['Wiki_Entity'].isin(nanotech_check_tech_list3))]['Wiki_Entity'].tolist()
len(nanotech_check_tech_list4)

# Pageviews_5yr_slope > 0
nanotech_check_tech_list5 = df_input[(df_input['ET7 theme clusters'] == 'Nanotechnology') & (~df_input['ET100_Flag'].isin(nanotech_check_tech_list1)) & (~df_input['Wiki_Entity'].isin(nanotech_check_tech_list2)) & (~df_input['Wiki_Entity'].isin(nanotech_check_tech_list3)) & (~df_input['Wiki_Entity'].isin(nanotech_check_tech_list4))].sort_values('cosine_dist_to_anchor')['Wiki_Entity'].tolist()
len(nanotech_check_tech_list5)

# sorted by cosine_dist_to_anchor
nanotech_check_tech_list6 = df_input[(df_input['ET7 theme clusters'] == 'Nanotechnology') & (~df_input['Wiki_Entity'].isin(nanotech_list))].sort_values('cosine_dist_to_anchor')['Wiki_Entity'].tolist()
len(nanotech_check_tech_list6)

# %%
autonomous_tech_list = ['Software-defined radio', 'Neutron imaging', 'Digital holography', 
                        'Super-resolution imaging', 'RF power amplifier', 'Fiber Bragg grating', 'Smart antenna', 
                        'Silicon photonics', 'Electrical discharge machining', 'Adaptive optics', 
                        'Battery management system', 'Fiber laser', 'Microwave imaging', 'Sensor', 
                        'Lithium-ion battery', 'Photodiode', 'Integrated circuit', 'Optical networking', 
                        'Satellite geodesy', 'Frequency comb', 'Power transmission', 'Signal processing', 
                        'Industrial robot', 'Fourier optics', 'Electro-optics', 'MOSFET', 
                        'Analog signal processing', 'Wireless power transfer', 'Spectral imaging', 'Pulsed power', 
                        'Optical fiber', 'Inertial confinement fusion', 'Digital signal processing', 
                        'Frequency selective surface', 'Digital holographic microscopy', 
                        'Semiconductor device fabrication', 'Avionics', 'Visible light communication', 'Li-Fi', 
                        'Electromagnetic shielding', 'Reconfigurable antenna', 'FinFET', 'Cognitive radio', 
                        'MIMO', 'MIMO-OFDM', 'Beamforming', 'Active noise control', 'RFIC', 'Acoustic emission', 
                        'Rapid tooling', 'Acoustic levitation', 'Magnetic levitation', 'Magnetic bearing', 
                        'Active vibration control', 'Telematics', 'Pedestrian detection', 
                        'Structural health monitoring', 'Confocal', 'Particle image velocimetry', 
                        'Tip-enhanced Raman spectroscopy', 'Ptychography', 'Reflectometry', 
                        'Photoacoustic spectroscopy', 'Free-space optical communication', 
                        'Distributed acoustic sensing', 'Optical communication', 'Attitude control', 
                        'Spacecraft thermal control', 'Autonomous underwater vehicle', 'NOTAR', 
                        'Synthetic vision system', 'Unmanned surface vehicle', 'Laser rangefinder', 
                        'Wafer-level packaging', 'Arc suppression', 'Transfer switch', 'Optical switch', 
                        'Optical storage', 'Place shifting', 'Signal compression', 'Envelope tracking', 
                        'Automated fiber placement', 'Holographic data storage', 'Wave radar', 'WiTricity', 
                        'Magnetic coupling', 'Electronic lock', 'Vehicle tracking system', 'Remote diagnostics', 
                        'Electromagnetic clutch', 'Wingsail', 'L-drive', 'Solar lamp', 
                        'Snapshot hyperspectral imaging', 'Active optics', 'Computer-generated holography', 
                        'Interferometric microscopy', 'Photon counting', 'Silicon photomultiplier', 
                        'Distributed temperature sensing']
print (len(autonomous_tech_list))

biotechnology_list = ['Neurotechnology', 'Functional magnetic resonance imaging', 'Medical robot', 'CRISPR', 
                      'Whole genome sequencing', 'Microarray', 'Synthetic vaccine', 'Solar chemical', 
                      'Fuel cell', 'Carbon capture and storage', 'Biosensor', 'Bioelectronics', 
                      'Virtual screening', 'Bioreactor', 'Sensory substitution', 
                      'Functional electrical stimulation', 'Biopreservation', 'Deep brain stimulation', 
                      'Functional neuroimaging', 'Laser ablation', 'Hydrogen technologies', 
                      'Precision agriculture', 'Neurorobotics', 'Smart lighting', 'Digital radiography', 
                      'Biological imaging', 'Calcium imaging', 'Liquid biopsy', 'Bioconjugation', 
                      'Electroporation', 'Live cell imaging', 'Functional imaging', 'Photoacoustic imaging', 
                      'Biocatalysis', 'Power system simulation', 'Preclinical imaging', 'Bio-MEMS', 
                      'DNA computing', 'Biocomposite', 'Smart polymer', 'Flow battery', 
                      'Electrochemical energy conversion', 'Bionics', 'Biorefinery', 
                      'Underground hydrogen storage', 'Molecular imaging', 'Magnetic particle imaging', 
                      'Biomechatronics', 'Microbial electrolysis cell', 'Cardiac imaging', 'Biochip', 
                      'Bioorthogonal chemistry', 'Microbial electrosynthesis', 'Bioproduction', 
                      'Photobioreactor', 'Brain mapping', 'Biomedical text mining',
                      'Digital pathology', 'Biorefining', 'Energy recovery', 'Neuroimaging', 'Machine olfaction', 
                      'Biomining', 'Eye tracking', 'Magnetoencephalography', 'Resting state fMRI', 
                      'Speech technology', 'Neuroprosthetics', 'Refractive surgery', 'Optogenetics', 
                      'Cochlear implant', 'Actigraphy', 'Neurostimulation', 'Tractography', 'Neurofeedback', 
                      'Capsule endoscopy', 'Minimally invasive spine surgery', 'Elastography', 
                      'X-ray microtomography', 'Cone beam computed tomography', 'Optical tomography', 
                      'Radiosurgery', 'Computer-assisted surgery', 'Image-guided surgery', 'Artificial cell', 
                      'Decellularization', 'Cell sorting', 'Mass cytometry', 'Targeted drug delivery', 
                      'High-throughput screening', 'Molecular breeding', 'Genome editing', 'Gene delivery', 
                      'Synthetic genomics', 'DNA synthesis', 'Nanopore sequencing', 'Single cell sequencing', 
                      'Artificial photosynthesis', 'Gas separation', 'Nanofiltration']
print (len(biotechnology_list))

converging_tech_list = ['3D printing', 'Augmented reality', 'Virtual reality', 'Assistive technology', 
                        'Wearable technology', 'Microgeneration', 'Microgrid', 'Smart grid', 'Photovoltaics', 
                        'Grid energy storage', 'Energy storage', 'Wave power', 'Robotics', 
                        'Autonomous car', 'Extended reality', 'Computer-aided technologies', 'Digital mapping', 
                        'Visual computing', 'Image fusion', 'Digital image processing', 'Machine perception', 
                        'Genetic algorithm', 'Geometry processing', 'Reversible computing', 'Marine energy', 
                        'Data fusion', 'Soft robotics', 'Robotic process automation', 'Mixed reality', 
                        'Autonomous robot', 'Smart meter', 'Video processing', 'Machine vision', 'Mobile robot', 
                        'Humanoid robot', 'Unconventional computing', 'Robotic materials', 'Swarm robotics', 
                        'Mechatronics', 'Soft computing', 'Legged robot', 'Extreme learning machine', 
                        'Uncertainty quantification', 'Robot navigation', 'Markov chain Monte Carlo', 
                        'Automated machine learning', 'Constrained optimization', 'Evolutionary algorithm', 
                        'Robot learning', 'Medical image computing', 'Natural computing', 'Social robot', 
                        'Array processing', 'Soft sensor', 'Digital architecture', 'Quantum machine learning',
                        'Statistical signal processing', 'Urban computing', 'Telerobotics', 
                        'Support vector machine', 'Physical computing', 'Bio-inspired computing', 
                        'Sensor fusion', 'Robot control', 'Digital soil mapping', 'Concentrated solar power', 
                        'Computational imaging', 'Evolvable hardware', 'Computerized adaptive testing', 
                        'Optical neural network', 'Advanced process control', 'Telepresence', 
                        'Mobile mapping', 'Real-time simulation', 'Adaptive filter', 'Image registration', 
                        'Content-based image retrieval', 'Generative adversarial network', 'Visual odometry', 
                        'Structure from motion', 'Point cloud', 'E-textiles', 'Immersive technology', 
                        'Driving simulator', 'Gesture recognition', 'Active vision', 'Object detection', 
                        'Face detection', '3D reconstruction', 'Light field', 'Automatic differentiation', 
                        'Lidar', 'Vehicle-to-grid', 'Visual servoing', 'Teleoperation', 'Real-time MRI', 
                        'Reverse image search', 'Hands-free computing', 'Animated mapping', 
                        'Probabilistic roadmap']
print (len(converging_tech_list))

data_analytics_list = ['Speech recognition', 'Semantic search', 'Blockchain', 'Cloud robotics', 'Knowledge Graph', 
                       'Smart contract', 'Neural machine translation', 'Complex event processing', 
                       'Distributed ledger', 'Cyber-physical system', 'Statistical machine translation', 
                       'Knowledge extraction', 'Artificial neural network', 'TensorFlow', 'OpenCV', 
                       'Convolutional neural network', 'Chatbot', 'Activity recognition', 'Machine translation', 
                       'Language identification', 'Speech synthesis', 'Language model', 'Deep learning',
                       'Natural language understanding', 'Information extraction', 'Ontology learning', 
                       'Natural language generation', 'Automatic summarization', 'Learning to rank', 
                       'Question answering', 'Web mining', 'Plagiarism detection', 'Entity linking', 
                       'Social media mining', 'Decision support system', 'Web intelligence', 
                       'Information integration', 'Text mining', 'DSpace', 'Dialog system', 
                       'Multimodal interaction', 'Hypertext', 'Process mining', 'Accounting information system', 
                       'Data extraction', 'Automated reasoning', 'Runtime verification', 'Formal verification', 
                       'Language-based security', 'Multi-agent system', 'Computational intelligence', 
                       'Cognitive robotics', 'Cloud gaming', 'Marketing automation', 'Media intelligence', 
                       'Warehouse management system', 'Transportation management system', 
                       'Warehouse control system', 'Logistics automation', 'Business process automation', 
                       'Speaker diarisation', 'Language Weaver', 'Interactive machine translation', 
                       'Semantic compression', 'Lexical substitution', 'Natural Language Toolkit', 
                       'Textual entailment', 'Multi-document summarization', 
                       'Data mapping', 'Named graph', 'Digital prototyping', 'Automatic bug fixing', 
                       'General-purpose modeling', 'Cloud-based integration', 'Data virtualization', 
                       'Pandoc', 'Ω-automaton', 'Abstract semantic graph', 'Intelligent decision support system', 
                       'Cloud collaboration', 'Multi-model database', 'General-purpose language', 
                       'Component-based usability testing', 'Augmented cognition', 'Attentive user interface', 
                       'Helmholtz machine', 'Liquid state machine', 'Neural Turing machine', 
                       'Reliability block diagram', 'Transfer-based machine translation', 
                       'Controlled natural language', 'Deep linguistic processing', 'Software intelligence', 
                       'Time-utility function', 'Schema evolution', 'Operational intelligence', 
                       'Autonomous agent', 'Procedural reasoning system', 
                       'Belief–desire–intention software model', 'Knowledge Query and Manipulation Language']
print (len(data_analytics_list))

health_medical_list = ['Virtual patient', 'Medical device', 'Algorithmic trading', 'High-frequency trading', 
                       'Health informatics', 'Connected health', 'Health technology', 'Digital phenotyping', 
                       'MHealth', 'Imaging informatics', 'EHealth', 'Telemedicine', 'Persuasive technology', 
                       'Educational technology', 'Telerehabilitation', 'Telehealth', 'Remote patient monitoring', 
                       'Artificial intelligence in healthcare', 'Process analytical technology', 
                       'Electronic communication network', 'Automated trading system', 'Weak AI', 
                       'Medical algorithm', 'Gustatory technology', 'Hypothetical technology', 'Social machine', 
                       'Patent visualisation', 'Human-based computation', 'AutoTutor', 'Coh-Metrix', 
                       'Medical logic module', 'Ultra-low latency direct market access', 'Cognitive tutor', 
                       'Energy Systems Language', 'Non-native speech database', 'ACT-R', 
                       'Future Attribute Screening Technology', 'Auction sniping', 'Social trading', 
                       'Herrmann Brain Dominance Instrument', 'SOAP note', 'Virtual world language learning', 
                       'Index arbitrage', 'Validation (drug manufacture)', 'Trading strategy', 
                       'Clinical documentation improvement', 'Biocommunication (science)', 
                       'Direct-access trading', 'NHS Connecting for Health', 'Continua Health Alliance',
                       'Forensic video analysis', 'Automated dispensing cabinet', 'Compulsion loop', 
                       'Biopsychosocial model', 'Offender Assessment System', 
                       'Medical toxicology', 'Knowledge transfer', 'Human-centered computing',
                       'Digital labor', 'Global mental health', 'Software studies', 'Knowledge translation',
                       'Computerized physician order entry', 'Digital literacy', 'Choose and Book', 
                       'Health literacy', 'Direct market access', 'Aerospace Valley', 
                       'Foreign exchange aggregator', 'Health care analytics', 'Decision aids',
                       'Telepathology', 'Chronic care management', 'Electronic data capture', 
                       'Consumer-driven healthcare', 'Electronic prescribing', 'Teledermatology',
                       'Home automation for the elderly and disabled', 'Medical billing', 
                       'Computer-supported collaboration', 'Simulated patient', 'Retail foreign exchange trading', 
                       'General purpose technology', 'Remote surgery', 'Enterprise master patient index', 
                       'Clinical data management', 'Remote therapy', 'Process validation', 'Brain fingerprinting', 
                       'Cross Enterprise Document Sharing', 'Digital collaboration', 'Laboratory informatics', 
                       'Speech translation', 'Point of care', 'Electronic Broking Services', 
                       'M-learning', 'Telecare', 'Pharmacy automation', 
                       'Information and communications technology', 'Cyberpsychology']
print (len(health_medical_list))

network_list = ['5G', 'Unified communications', 'Financial technology', 'Local positioning system',
                'Homomorphic encryption', 'Identity management', 'Computer security', 'Virtual assistant',
                'Grid computing', 'Network virtualization', 'Digital security', 'Post-quantum cryptography',
                'Network function virtualization', 'Trusted Computing', 'Energy harvesting', 
                'Software-defined networking', 'Building automation', 'Stream processing', 'Mobile computing', 
                'Embedded software', 'Digital electronics', 'Home automation', 'Wireless network', 
                'Semiconductor memory', 'Laser scanning', 'Wireless sensor network', 'Hardware security', 
                'Heterogeneous computing', 'Stochastic computing', 'Mobile cloud computing', 
                'Information-centric networking', 'Exascale computing', 'Terabit Ethernet',
                'Low-power electronics', 'Time-Sensitive Networking', 'Wireless mesh network', 
                'Reconfigurable computing', 'Routing protocol', 'Ad hoc network', 'Cellular network', 
                'Mobility management', 'Optical interconnect', 'Maglev', 'VLSI Technology', 'Circuit design', 
                'Functional verification', 'Secure multi-party computation', 'Privacy-enhancing technologies', 
                'Network security', 'Processor design', 'Mobile technology', 'Edge device', 
                'Synchronous Ethernet', 'Backbone network', 'Data transmission', 'Contactless payment',
                'Telecommunications Management Network', 'Roofnet', 'Common-channel signaling', 
                'Multicast encryption', 'Network mapping', 'Ultra-wideband', 'Digital AMPS', 
                'Satellite constellation', 'Fixed–mobile convergence', 'ControlNet', 'Consumer IR', 
                'Data cable', 'Cable management', 'Unified Payments Interface', 
                'Remote deposit', 'MobilePay', 'Virtual advertising', 'Barcode printer', 
                'Resolution enhancement technology', 'Under vehicle inspection', 'Intelligent speed adaptation', 
                'Automatic number-plate recognition', 'Analogue electronics', 'Semiconductor process simulation', 
                'PLECS', 'Quite Universal Circuit Simulator', 'End-to-end encryption', 'Verifiable computing', 
                'Authenticated encryption', 'File integrity monitoring', 'Dynamic recompilation', 
                'Vision processing unit', 'Speculative multithreading', 'Fabric computing', 
                'High-throughput computing', 'Mobile wireless sensor network', 'Positioning system', 
                'Optical mesh network', 'Point-to-multipoint communication', 'Super Wi-Fi', 'Network tomography', 
                'Contact image sensor', 'Tiled rendering', 'Smart thermostat']
print (len(network_list))

nanotech_list = ['Quantum sensor', 'Optical computing', 'Quantum computing', 'Smart material', 
                 'Quantum information science', 'Photoelectrochemistry', 'Computational electromagnetics', 
                 'Electrospinning', 'Pulsed laser deposition', 'Laser cooling', 'Nanoelectronics', 
                 'Strain engineering', 'Electronic skin', 'Thermoelectric generator', 'Laser beam welding', 
                 'Electron tomography', 'Electronic nose', 'Failure analysis', 'Semiconductor', 
                 'Optoelectronics', 'Photonics', 'Quantum key distribution', 'Flexible electronics', 
                 'Quantum algorithm', 'Electrowetting', 'Electronic packaging', 'Printed electronics', 
                 'Scanning transmission electron microscopy', 'Free-electron laser', 'Quantum imaging',
                 'Photonic integrated circuit', 'Electroactive polymers', 'Quantum cryptography', 
                 'Selective laser sintering', 'Electron spectroscopy', 'Digital microfluidics', 
                 'Electron energy loss spectroscopy', 'Molecular electronics', 'Plasma processing', 
                 'Quantum error correction', 'Nanosensor', 'Plasma electrolytic oxidation', 'Ghost imaging', 
                 'Mass spectrometry imaging', 'Dielectrophoresis', 'Organic electronics', 
                 'Selective laser melting', 'Capacitive deionization', 'Microwave chemistry', 'Nanofluidics', 
                 'Soft lithography', 'Surface plasmon resonance', 'Rapid prototyping', 'Thermal barrier coating', 
                 'Magnetic refrigeration', 'Spintronics', 'Micromagnetics', 'Computational lithography', 
                 'Photolithography', 'Nanoimprint lithography', 'Microfabrication', 'Photon upconversion', 
                 'Ion beam', 'Photocatalysis', 'Plasma polymerization', 'Plasma etching', 
                 'Chemical vapor deposition', 'Ion implantation', 'Epitaxy', 'Atomic layer deposition', 
                 'Piezotronics', 'Computational magnetohydrodynamics', 'Hamiltonian optics', 
                 '5D optical data storage', 'Thermal management (electronics)', 'Thick-film technology', 
                 'Electron-beam technology', 'Thermophotovoltaic', 'NASA spinoff technologies', 
                 'Quantum dot display', 'Rapid thermal processing', 'Heat-assisted magnetic recording', 
                 'Molecular scale electronics', 'Reverberation mapping', 'Continuous ink system', 
                 'Through-silicon via', 'Metamaterial cloaking', 'Nanocircuitry', 'Quantum technology', 
                 'Laser-hybrid welding', 'Superconducting quantum computing', 'Quantum network', 
                 'Nanolaser', 'Nanowire battery', 'One-way quantum computer', 'Ultramicroelectrode', 
                 'Quantum simulator', 'Spin transistor', 'Next-generation lithography', 'Nanogenerator']
print (len(nanotech_list))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
df_tech_checked = pd.DataFrame(autonomous_tech_list + biotechnology_list + converging_tech_list + data_analytics_list + health_medical_list + network_list + nanotech_list, columns = ['Wiki_Entity'])
df_tech_checked = df_tech_checked.merge(df_input[['Wiki_Entity', 'ET7 theme clusters']], how = 'left', left_on = 'Wiki_Entity', right_on = 'Wiki_Entity')
df_tech_checked

# %%
# for i in nanotech_check_tech_list2:
#     print ('What is "{0}"? Is it a technology?'.format(i))
#     print ('\n')
# #     print (i)

# %%
# index = 0 + 50 * 0
# print ("Please find exact technologies in the following list:")
# for i in health_medical_list[index:]:
    
#     print (i)

# %%
# print ("Please find exact technologies in the following list:")
# index = 0 + 50 * 1

# for i in nanotech_check_tech_list6[index: index + 50]:
#     print ('What is "{0}"? Is it a technology?'.format(i))
#     print ('\n')
# #     print (i)

# %%
# print ("Please find exact technologies in the following list:")
# for i in nanotech_check_tech_list2:
#     print ('What is "{0}"? Is it a technology?'.format(i))
#     print ('\n')
# #     print (i)

# %%
df_input
# Out:
#                      Wiki_Entity                       ET3 meta-clusters  \
# 0                  User analysis  Information & Communication Technology
# 1                User assistance  Information & Communication Technology
# 2                    RITE Method  Information & Communication Technology
# 3      Electronic meeting system  Information & Communication Technology
# 4                       ISO 9241  Information & Communication Technology
# ...                          ...                                     ...
# 23539                 Methanogen  Life Sciences & Human-computer Systems
# 23540             Methanogenesis  Life Sciences & Human-computer Systems
# 23541  Anoxygenic photosynthesis  Life Sciences & Human-computer Systems
# 23542                    Anammox  Life Sciences & Human-computer Systems
# 23543      Denitrifying bacteria  Life Sciences & Human-computer Systems
#
#       ET7 theme clusters  Pageviews_2019  Pageviews_2020  Pageviews_2021  \
# ...

# %%
df_wk_id = pd.read_csv('Datasets/Original_ET50k_unique_Wikidata_ID.csv')
df_wikidata_info = pd.read_csv('Datasets/ET50k_Wikidata_info.csv')
df_non_tech = df_wk_id[~df_wk_id['Technology'].isin(df_input['Wiki_Entity'])]
df_non_tech = df_non_tech.drop_duplicates('Wikidata_ID')
df_non_tech = df_non_tech.merge(df_wikidata_info, how = 'left', left_on = 'Wikidata_ID', right_on = 'Wikidata_ID')
# df_non_tech = df_non_tech[(~df_non_tech['Description'].isna()) & (df_non_tech['instance of'].isna()) & (df_non_tech['subclass of'].isna())]
# df_non_tech_checked = df_non_tech[~df_non_tech['Description'].str.contains('techn')]

# %%
non_tech_list = ['IEEE Industrial Electronics Society', 'Cyborg anthropology', 'Radical Evolution', 
                 "Moore's law", 'Ephemeralization', 'Democratic rationalization', 'R&D management', 
                 'Outline of transhumanism', 'Outline of artificial intelligence', 'Antifragility',
                 'Conceptual dependency theory', 'Melvin Kranzberg', 'Centre for the Study of Existential Risk', 
                 'Knowledge level modeling', 'Instrumental convergence', 'The Wealth of Networks', 
                 'Global value chain', 'Daniel Crevier', 'Leslie P. Kaelbling', 'Julian Savulescu', 
                 'Transhumanist politics', 'Pioneer Award in Nanotechnology', 'Race Against the Machine', 
                 'Large technical system', 'Colors of biotechnology', 'Joseph Polchinski', 'Preorder economy', 
                 'Qualification problem', 'Machine Intelligence Research Institute', 'Organisational semiotics', 
                 'Superintelligence: Paths, Dangers, Strategies', 'Outline of thought', 'Bioconservatism', 
                 'Manufacturing', 'Mimetic isomorphism', 'Specialization of knowledge', 'Program derivation', 
                 'Attention schema theory', 'Product lifecycle', 'Singularitarianism', 'No-hiding theorem', 
                 'Techno-progressivism', 'Waterloo Institute for Nanotechnology', 'Virtual Health Library', 
                 'Evolving the Alien', 'Postanalytic philosophy', 'Qualitative research', 'Collaborative fiction', 
                 'International Council on Nanotechnology', 'Alphabet of human thought', 'Randal A. Koene', 
                 'Martha E. Pollack', 'Posthumanism', 'Innovacorp', 'Technology acceptance model', 
                 'Medical cybernetics', 'Sociotechnical system', 'Energy cannibalism', 'Oxygen cycle', 
                 'ADDIE Model', 'Technological singularity', 'George A. Bekey', 'Human capital flight', 
                 'Control theory', 'E-social science', 'Mathematical physiology', 'The Astonishing Hypothesis', 
                 'IEEE Cledo Brunetti Award', 'Domain knowledge', 'CogPrints', 'Patrick Winston', 
                 'Journal of Knowledge Management Practice', 'Blue Ocean Strategy', 'Technocentrism', 
                 'Quasi-empirical method', 'Script theory', 'Climatology', 'Digital sociology', 'Unorganisation', 
                 'Psychophysical parallelism', 'Critical Gameplay', 'Dispersed knowledge', 'Pattern theory', 
                 'Heideggerian terminology', 'Logic form', 'Helen Nissenbaum', 'Algorithmic learning theory', 
                 'Flash lag illusion', 'Non-spiking neuron', 'Rationality and Power', 'Digital philosophy', 
                 'Decoy effect', 'Computing Community Consortium', 'Discrete system', 'No Silver Bullet', 
                 'Experimental Mechanics', 'Eclipse Trilogy', 'Generativity', 'AI takeover', 'Demand forecasting', 
                 'Yseop', 'Cluster Innovation Centre', 'Ramification problem', 'Mathematical theory', 
                 'Actor–network theory', 'Humanitarianism', 'Hybrid logic', 'Naturalized epistemology', 
                 'Minatec', 'Telecommunications forecasting', 'Logical reasoning', 'Crossing the Chasm', 
                 'Formal Methods Europe', 'Marooned in Realtime', 'Desertec', 'Ringelmann effect', 
                 'Psycoloquy', 'Storyspace', 'Computational scientist', 'Social translucence', 'Naïve realism', 
                 'Efficient coding hypothesis', 'Boolean algebra', 'COSMOS cohort study', 'Critical design', 
                 'Metabolite damage', 'Bicycle tree', 'Autogenic succession', 'Autopoiesis', 'Compatibilism', 
                 'Carbon cycle re-balancing', 'Greenhouse gas emissions accounting', 'Motor imagery', 
                 'Correspondence problem', 'Effective altruism', 'Chemoaffinity hypothesis', 'Inclusive business', 
                 'Superdeterminism', 'Directed panspermia', 'Post-convergent', 'Andrew Ng', 'Bin packing problem', 
                 'Preferential looking', 'Risk compensation', 'Bias–variance tradeoff', 'Eliminative materialism', 
                 'NASA Advanced Space Transportation Program', 'Homayoon Kazerooni', 'Cognitivism (psychology)', 
                 'Universal approximation theorem', 'Technological utopianism', 'Glossary of robotics', 
                 'Kestrel Institute', 'Start-Up Chile', 'Safety property', 'Quantum Aspects of Life', 
                 'Rhythmanalysis', 'Global Environment for Network Innovations', 'Market analysis', 
                 'Cosmic microwave background', 'Extended cognition', 'High-level equilibrium trap', 
                 'Unruh effect', '10/90 gap', 'Event reconstruction', 'Opportunity management', 
                 'Fisheries management', 'Reactome', 'Shiv Nadar University', 'World disclosure', 
                 'Weak ontology', 'Theory-ladenness', 'Bright green environmentalism', 'Specific surface energy', 
                 'Manteia Predictive Medicine', 'Lévy flight foraging hypothesis', 'Connectivism', 
                 'Kilogram', 'Business interoperability interface', 'Genetically modified organism', 
                 'Bounded rationality', 'Fairphone', 'Carbon dioxide', 'List of omics topics in biology', 
                 'Correlates of War', 'Ford Airstream', 'Nonequilibrium Gas and Plasma Dynamics Laboratory', 
                 'Hazard', 'The Tech Awards', 'Lighthill report', 'Manchester Institute of Innovation Research', 
                 'Conversation theory', 'Space Studies Institute', "Brooks's law", 'Barcan formula', 
                 'Center for Sustainable Global Enterprise', 'Language Technologies Institute', 
                 'Tampere University of Technology', 'The Age of Spiritual Machines', 'Consumer privacy', 
                 'Science policy', 'Timeline of carbon nanotubes', 'Outline of philosophy', 'Gingivoplasty', 
                 'European Neural Network Society', 'Poverty of the stimulus', 'CPM-GOMS', 'Cell (biology)', 
                 'Boundary object', 'Vega Science Trust', 'Resource Extraction Monitoring', 
                 "Building Harlequin's Moon", 'Centre for Development of Advanced Computing', 
                 'Biological naturalism', 'Virginia Smart Road', '19th-century turnpikes in Massachusetts', 
                 '2009 Southeast Asian haze', 'A New Deal for Transport: Better for everyone', 
                 'Abstract particulars', 'Actuarial Society of South Africa', 'Adhimoksha', 'CONWIP', 
                 'Aggressiveness strategy', 'Alberta Council on Admissions and Transfer', 'Ali Malkawi', 
                 'Ama (ayurveda)', 'American and British English spelling differences', 'Traffic count', 
                 'Anaerobic contact process', 'Analytical phonics', 'Anatman (Hinduism)', 'Netcode', 
                 'Ancient Commentators on Aristotle project', 'Aptivate', 'Arctic Research Foundation', 
                 'Arthropod gap', 'Artificial intelligence, situated approach', 'Full-spectrum dominance', 
                 'Association of Independent Professionals and the Self-Employed', 'Inductive reasoning aptitude', 
                 'Astrobiology Society of Britain', 'AttentionTracking', 'Attributable risk percent', 
                 'Attrition (medicine, epidemiology)', 'Australian Psychology Accreditation Council', 
                 'Awards of the British Academy', "Backing Australia's Ability", 'Hawking radiation', 
                 'Bangladesh Institute of Peace & Security Studies', 'Basal (medicine)', 'BCS-FACS', 
                 'Best of Biotech', 'Bikeway safety', 'Binding neuron', 'Boreal Forest Conservation Framework', 
                 'Bornhuetter-Ferguson method', 'Brace matching', 'Bridge program (higher education)', 
                 'Brittle Books Program', 'Bumblebee models', "Busemann's Biplane", 'Social genome', 
                 'Canada Education Savings Grant', 'Mathematical universe hypothesis', 'Cellular differentiation', 
                 'Canada Social Transfer', 'Canadian Power and Sail Squadrons', 'Capital Jury Project', 
                 'CAPRISA 004', 'CARINE', 'Epistemological solipsism', 'NeuroRacer', 'Strategic foresight', 
                 'Causes of income inequality in the United States', 'CDM Gold Standard', 'Centauro event', 
                 'Center for BrainHealth', 'Center for Regulatory Effectiveness', 'Knowledge mobilization', 
                 'Centre for Military and Strategic Studies', 'Combinatorial explosion', 'Syntheism', 
                 'Centre for Philosophy of Natural and Social Science', 'Certificate of Sixth Year Studies', 
                 'Certified Protection Officer', 'China Open Resources for Education', 'CR Society International', 
                 'Crosby–Kugler capsule', 'DASH7 Alliance', 'Debates within libertarianism', 
                 'Defence Centre of Training Support', 'Defence Industrial Strategy', 'Maximum subarray problem', 
                 'Defense Centers of Excellence for Psychological Health and Traumatic Brain Injury', 
                 'Designs of the Time', 'Computer Networks (journal)', 'Canadian Biodiversity Strategy', 
                 'Division of Acquired Immunodeficiency Syndrome', 'Ecological inheritance', 'Economic puzzle', 
                 'Economy-wide material flow accounts', 'Embodied bilingual language', 'State consequentialism', 
                 'Empirical limits in science', 'Environment Conservation Group', 'European Employment Strategy', 
                 'European Group on Tort Law', 'European Internet Accessibility Observatory', 
                 'European Land-Robot Trial', 'European Privacy Association', 'Event-related optical signal', 
                 'Ex parte Lundgren', 'Excellence in Cities', 'Expected transmission count', 'Explorer AUV', 
                 'Extensional and intensional definitions', 'Face Animation Parameter', 'The Lean Startup', 
                 'Federal Networking Council', 'Ferroelectric polymers', 'FFAG accelerator', 
                 'Five Year Forward View', 'Fraud-on-the-market theory', 'Fredkin finite nature hypothesis', 
                 'Future map (organizational planning)', 'Garib Sena', 'Glob (visual system)', 
                 'Great Recession in Europe', 'Great Trade Collapse', 'Groupe INTRA', 'Hackers.mu', 
                 'Health Impact Fund', "Healthcare Businesswomen's Association", 'ISTE Standards', 
                 'Heterochrony', 'Humanitarian Response Index', 'ICL Direct Machine Environment', 
                 'Instantaneous phase', 'Institute for 21st Century Agoras', 'Communicating sequential processes', 
                 'Institute for Healthcare Improvement', 'Institute for Learning and Teaching in Higher Education',
                 'International Assessment of Agricultural Knowledge, Science and Technology for Development', 
                 'International Society for NeuroVirology', 'International Society for Pharmaceutical Engineering', 
                 'International Virtual Observatory Alliance', 'Internet Universality', 'Algorithmic skeleton', 
                 'Investor Network on Climate Risk', 'Ionian Enlightenment', 'Human action cycle', 
                 'Jerome C. Hunsaker Visiting Professor of Aerospace Systems', 'Jesse Fried', 'Jiangbeizui CBD', 
                 'Joint Capabilities Integration Development System', 'Joint Mathematical Council', 
                 "Kirk's Fire Investigation", 'KISKA', 'Knowledge Systems Laboratory', 'Switching lemma', 
                 'Language/action perspective', 'Lemur Project', 'Link group', 'Dematerialization (economics)', 
                 'Marine energy management', 'Market environment', 'Materials system', 'Media Key Block', 
                 'Medical Practitioners Disciplinary Tribunal', 'Meyerhoff Scholarship Program', 
                 'Michigan Aeronautical Research Center', 'Mike & Ophelia Lazaridis Quantum-Nano Centre', 
                 'Mimas (data centre)', 'Modalities (sociology)', 'MOF Model to Text Transformation Language', 
                 'Moire deflectometry', 'Mortality Medical Data System', 'Network economics', 
                 'MTA SZTAKI Laboratory of Parallel and Distributed Systems', 'MVEDR', 'Mythology of Stargate', 
                 'Napier Oryx', 'National Assessment Bank', 'National Exposure Research Laboratory', 
                 'National Institute for Computational Sciences', 'National Key Disciplines', 
                 'National Livestock Identification System', 'Optics and Photonics News', 'Effortfulness', 
                 'National Resource Center for Health Information Technology', 'Nature Society (Singapore)', 
                 'Neglected tropical disease research and development', 'New Approach to Appraisal', 
                 "New Partnership for Africa's Development E-School Program", 'New security concept', 
                 'Nonlinear pricing', 'North American Native Fishes Association', 'North East Humanists', 
                 'North Sea Region Programme', 'Nuker Team', 'NYU Stern Center for Business and Human Rights', 
                 'Observations of daily living', 'Oil imperialism theories', 'OpenVPX', 'Availability heuristic', 
                 'Pacific Ocean Shelf Tracking Project', 'Planetary phase of civilization', 'Plekton', 
                 'Plug-in Hybrid Electric Vehicle Research Center', 'Post-Critical', 'Precipitationshed', 
                 'Primal Integration', 'Principles of European Tort Law', 'Prony equation', 'Informatics Forum', 
                 'Psychology of previous investment', 'Public participation geographic information system', 
                 'Purity (gas)', 'Quantity adjustment', 'Real Time Information Group', "Koomey's law", 
                 'Recursive competitive equilibrium', 'Regenerative Medicine Partnership in Education', 
                 'Registered Science Technician', 'Registered Scientist', 'Resolvent (Galois theory)', 
                 'Responsible autonomy', 'Reuters Digital Vision Program', 'Riversimple Urban Car', 
                 'San Francisco Ethics Commission', 'School of Literature, Media, and Communication', 
                 'SCRIPT (AHRC Centre)', 'Sectoral currency', 'Segal Design Institute', 'Sensation (fiction)', 
                 'SIEPAC', 'Situational analysis', 'Slipstream (science fiction)', 'Technology policy', 
                 'Sociology of valuation', 'Soft energy technology', 'Duration (philosophy)', 
                 'Software release train', 'Species pool', 'Stanford Natural Language Processing Group', 
                 'Start Input/Output', 'Styles of Chinese martial arts', 'Swarm Development Group', 
                 'Talking tactile tablet', 'Tamil Nadu Science Forum', 'Tarner Lectures', 'Tattvasamgraha', 
                 'Tensor product model transformation', 'The British Vacuum Council', 'Tieline', 
                 'Tools and Trades History Society', 'Transaction Workflow Innovation Standards Team', 
                 'Trigger (particle physics)', 'Triune continuum paradigm', 'Tucson Amateur Packet Radio', 
                 'Tufts OpenCourseWare', 'Tweel (A Martian Odyssey)', "Kerner's breakdown minimization principle", 
                 'U.S. Commission on National Security/21st Century', 'UNESCO Science Report', 
                 'United Kingdom Accreditation Forum', 'Universities Funding Council', 'Customer data platform', 
                 'University Professors Program', 'Wired for Management', 'Wolf effect', 'Wuxi New Area', 
                 'Y Chromosome Consortium', 'Z User Group', 'Zoom creep', 'Imponderable fluid', 
                 'Problem of mental causation', 'Labshare', 'Quantum Philosophy', 'Subvocalization', 
                 'Internet research ethics', 'Protein', 'Bradford Hill criteria', 'Call2Recycle', 
                 'Flexible purpose corporation', 'Comprehensive National Power', 'D20 Future', 
                 'Socio-ecological system', 'Evolution', 'Basel Declaration', 'Sogeti', 'Safehold', 
                 'European Schoolnet', 'Harebrained Schemes', 'Network Centric Operations Industry Consortium', 
                 'Learning-by-doing (economics)', 'Musical instrument classification', 'Haddon Matrix', 
                 'Strategic human resource planning', 'Population process', 'Attention economy', 
                 'Innovation economics', 'Open research', 'Hypercar (concept car)', 'Heuristic evaluation', 
                 'Constructivism (philosophy of education)', 'Preference utilitarianism', 'ISO 10006', 
                 'Algorithmic bias', 'Bibliographic coupling', 'Task Force Scorpio', 'Neocatastrophism', 
                 "Bremermann's limit", 'Crysis 3', 'CMBFAST', 'Keratoprosthesis', 'Technogaianism', 
                 'Advanced Extension Award', 'Grounded theory', 'Computable function', 'Mind–body dualism', 
                 'Singularity (mathematics)', 'Recruitment', 'Contingent claim', 'Contrast transfer function', 
                 'Service management', 'McCumber relation', 'Free energy principle', 'Complex system', 
                 'Peak oil', 'Valiant–Vazirani theorem', 'Intergalactic Computer Network', 'Feynman diagram', 
                 'Cartesian materialism', 'Solution architect', 'Export Administration Regulations', 
                 'NIOSH Power Tools Database', 'Biosocial theory', 'Comparison of Java and C++', 'Food Race', 
                 'Kano model', 'System Rush', 'Prato reaction', 'Cartesianism', "Ohm's acoustic law", 
                 'Peer-to-peer renting', 'Young–Helmholtz theory', 'Sensory nervous system', 'J. Anthony Movshon', 
                 'World Usability Day', 'Enumerative induction', 'Rigi (software)', 'Discourse on the Method', 
                 'Theory of everything (philosophy)', 'Multiple drafts model', 'Oxford Martin School', 
                 'Planned obsolescence', 'Senescence', 'Knowledge gap hypothesis', 'Sentiocentrism', 
                 'Knowledge management', 'Graphic communication', 'Lego Serious Play', 'Energy policy of India', 
                 'Launch and Early Orbit phase', 'Potential energy', 'Surfboard', 'Advertising media selection', 
                 'Lib Sh', 'Boolean Pythagorean triples problem', 'Drake equation', 'Frictional Games', 
                 'Indore Bus Rapid Transit System', 'OODA loop', 'CourseSmart', "Gabbay's separation theorem", 
                 'Before You Know It (software)', 'Kardashev scale', 'Boltzmann brain', 'EQ-5D', 'Medical test', 
                 'Abundance: The Future Is Better Than You Think', 'Kaya identity', 'Counterfactual definiteness', 
                 'Rabies immunoglobulin', 'Anekantavada', 'Chemical specificity', 'Mathematicism', 
                 'Greenhouse debt', 'Feature-driven development', 'Programming Research Group', 'P3M', 
                 'Indigo Line', 'Preformationism', 'Social intuitionism', 'Benefits realisation management', 
                 'Findability', 'Fermi paradox', 'IEEE Power & Energy Society', 'CCIE Certification', 
                 'Physics envy', 'Hockney–Falco thesis', 'DRDO Self Propelled Mine Burier', 'Truth-value link', 
                 'Manufacturing Advisory Service', 'Zombies, Run!', 'Meta Content Framework', 'JumpStartFund', 
                 'Decorrelation theory', 'Epistemological pluralism', 'Kuramoto model', 'STRIDE (security)', 
                 'Global Telecoms Exploitation', 'Weak central coherence theory', 'Hornby Virtual Railway', 
                 'Market for zero-day exploits', 'No-communication theorem', 'Therapy', 'Theory of mind', 
                 'Highly optimized tolerance', 'Libidinal Economy', 'IB Group 4 subjects', 
                 'Quantum entanglement', 'Cosmic string', 'Speculative evolution', 'Logicism', 
                 'Von Neumann–Wigner interpretation', 'Anomalous monism', 'Speculative damages', 
                 'RIKEN Quantitative Biology Center', 'Terasem Movement', 'Graph edit distance', 
                 'Napierian logarithm', 'U15 Group of Canadian Research Universities', 'User error', 
                 'Borwein integral', 'Jurassic World Evolution', 'Technics and Civilization', 
                 'Sequence space (evolution)', 'Mars Gravity Biosatellite', 'Logic and rationality', 
                 'Cyberfeminism', 'Cuspy halo problem', 'Knowledge building', 'RV Investigator', 
                 "Hamilton's principle", 'Database of Molecular Motions', 'Functional management',
                 'Formative context', 'Turing completeness', 'Landes Bioscience', 'Zero-player game', 
                 'Hubble Ultra-Deep Field', 'International Classification for Standards', 
                 'Department of Essential Drugs and Medicines', 'Wheeler–Feynman absorber theory', 
                 'System of concepts to support continuity of care', 'Deployable Virtual Training Environment', 
                 'TrackIR', 'UML Partners', 'Extracellular field potential', 'H-Bio', 'Biological system',
                 'Ghirardi–Rimini–Weber theory', 'Patent privateer', 'Methuselah Foundation', 
                 'Decision field theory', 'Europarl Corpus', 'Ozone', 'Biodiversity', 'Mental process', 
                 'Stimulus–response model', 'Negation normal form', 'Eco-investing', 'DeepCwind Consortium', 
                 'Mondex', 'Simulation hypothesis', 'Data activism', 'Chain fountain', 'Corpuscularianism', 
                 'Online shaming', 'Cognitive map', 'Immerman–Szelepcsényi theorem', 'EUREL', 
                 'Core competency', 'Asteroid impact avoidance', 'Moralistic fallacy', 'Gene structure', 
                 'Integrated Architecture Framework', 'S2P (complexity)', 'Nematicon', 'The Blue Economy', 
                 'Scale-space segmentation', 'Euromatrix', 'Resource productivity', 'COSTART', 'Reference beam', 
                 'Church–Turing thesis', 'Analytic–synthetic distinction', 'A3 problem solving']
print (len(non_tech_list))
# Out:
# 700

# %%
df_non_tech_checked = pd.DataFrame(non_tech_list, columns = ['Wiki_Entity'])
# df_non_tech_checked.to_csv('Datasets/Non_Tech_List.csv', index = False)

# %%
index = 0 + 50 * 66
print ('Which of the following items in the list "look like" technologies but are clearly not technologies?')
for i in df_non_tech['Technology'][index: index + 50]:
    print (i)
# Out:
# Which of the following items in the list "look like" technologies but are clearly not technologies?
# Commodity chain
# Long Reach Ethernet
# Detailed logarithmic timeline
# Computer music
# Laser Focus World
# Capacitance–voltage profiling
# Bloodlines (Star Trek: The Next Generation)
# Volvo V70
# Logical Methods in Computer Science
# Open assessment
# Electrode array
# Hard science fiction
# Regret (decision theory)
# Citroën Berlingo électrique
# Exhausted combination doctrine
# Case study
# Windows 10
# KMS (hypertext)
# Consider Phlebas
# Association of Professional Futurists
# Rajasthan Pre-Engineering Test
# Jim Woodcock
# Schulich School of Engineering
# Reach for Infinity
# IEC 62196
# Enterprise Mashup Markup Language
# Nils John Nilsson
# List of autonomous higher education institutes in India
# Dead-end elimination
# Cybernetics and Human Knowing
# ASA Silver Medal
# Sega VR
# Raghunath Anant Mashelkar
# Knowledge and Its Limits
# Technological determinism
# ...

# %%
# # Create a Pandas Excel writer using XlsxWriter as the engine.
# writer = pd.ExcelWriter("Technology_Classifier_Input_Samples.xlsx", engine="xlsxwriter")

# # Write each dataframe to a different worksheet.
# df_tech_checked.to_excel(writer, sheet_name="Tech", index = False)
# df_non_tech_checked[['Technology', 'Wikidata_ID', 'Description']].to_excel(writer, sheet_name="Not_Tech", index = False)

# # Close the Pandas Excel writer and output the Excel file.
# writer.close()

# %%
autonomous_tech_list = ['Software-defined radio', 'Neutron imaging', 'Digital holography', 
                        'Super-resolution imaging', 'RF power amplifier', 'Fiber Bragg grating', 'Smart antenna', 
                        'Silicon photonics', 'Electrical discharge machining', 'Adaptive optics', 
                        'Battery management system', 'Fiber laser', 'Microwave imaging', 'Sensor', 
                        'Lithium-ion battery', 'Photodiode', 'Integrated circuit', 'Optical networking', 
                        'Satellite geodesy', 'Frequency comb', 'Power transmission', 'Signal processing', 
                        'Industrial robot', 'Fourier optics', 'Electro-optics', 'MOSFET', 
                        'Analog signal processing', 'Wireless power transfer', 'Spectral imaging', 'Pulsed power', 
                        'Optical fiber', 'Inertial confinement fusion', 'Digital signal processing', 
                        'Frequency selective surface', 'Digital holographic microscopy', 
                        'Semiconductor device fabrication', 'Avionics', 'Visible light communication', 'Li-Fi', 
                        'Electromagnetic shielding', 'Reconfigurable antenna', 'FinFET', 'Cognitive radio', 
                        'MIMO', 'MIMO-OFDM', 'Beamforming', 'Active noise control', 'RFIC', 'Acoustic emission', 
                        'Rapid tooling', 'Acoustic levitation', 'Magnetic levitation', 'Magnetic bearing', 
                        'Active vibration control', 'Telematics', 'Pedestrian detection', 
                        'Structural health monitoring', 'Confocal', 'Particle image velocimetry', 
                        'Tip-enhanced Raman spectroscopy', 'Ptychography', 'Reflectometry', 
                        'Photoacoustic spectroscopy', 'Free-space optical communication', 
                        'Distributed acoustic sensing', 'Optical communication', 'Attitude control', 
                        'Spacecraft thermal control', 'Autonomous underwater vehicle', 'NOTAR', 
                        'Synthetic vision system', 'Unmanned surface vehicle', 'Laser rangefinder', 
                        'Wafer-level packaging', 'Arc suppression', 'Transfer switch', 'Optical switch', 
                        'Optical storage', 'Place shifting', 'Signal compression', 'Envelope tracking', 
                        'Automated fiber placement', 'Holographic data storage', 'Wave radar', 'WiTricity', 
                        'Magnetic coupling', 'Electronic lock', 'Vehicle tracking system', 'Remote diagnostics', 
                        'Electromagnetic clutch', 'Wingsail', 'L-drive', 'Solar lamp', 
                        'Snapshot hyperspectral imaging', 'Active optics', 'Computer-generated holography', 
                        'Interferometric microscopy', 'Photon counting', 'Silicon photomultiplier', 
                        'Distributed temperature sensing']
print (len(autonomous_tech_list))

biotechnology_list = ['Neurotechnology', 'Functional magnetic resonance imaging', 'Medical robot', 'CRISPR', 
                      'Whole genome sequencing', 'Microarray', 'Synthetic vaccine', 'Solar chemical', 
                      'Fuel cell', 'Carbon capture and storage', 'Biosensor', 'Bioelectronics', 
                      'Virtual screening', 'Bioreactor', 'Sensory substitution', 
                      'Functional electrical stimulation', 'Biopreservation', 'Deep brain stimulation', 
                      'Functional neuroimaging', 'Laser ablation', 'Hydrogen technologies', 
                      'Precision agriculture', 'Neurorobotics', 'Smart lighting', 'Digital radiography', 
                      'Biological imaging', 'Calcium imaging', 'Liquid biopsy', 'Bioconjugation', 
                      'Electroporation', 'Live cell imaging', 'Functional imaging', 'Photoacoustic imaging', 
                      'Biocatalysis', 'Power system simulation', 'Preclinical imaging', 'Bio-MEMS', 
                      'DNA computing', 'Biocomposite', 'Smart polymer', 'Flow battery', 
                      'Electrochemical energy conversion', 'Bionics', 'Biorefinery', 
                      'Underground hydrogen storage', 'Molecular imaging', 'Magnetic particle imaging', 
                      'Biomechatronics', 'Microbial electrolysis cell', 'Cardiac imaging', 'Biochip', 
                      'Bioorthogonal chemistry', 'Microbial electrosynthesis', 'Bioproduction', 
                      'Photobioreactor', 'Brain mapping', 'Biomedical text mining',
                      'Digital pathology', 'Biorefining', 'Energy recovery', 'Neuroimaging', 'Machine olfaction', 
                      'Biomining', 'Eye tracking', 'Magnetoencephalography', 'Resting state fMRI', 
                      'Speech technology', 'Neuroprosthetics', 'Refractive surgery', 'Optogenetics', 
                      'Cochlear implant', 'Actigraphy', 'Neurostimulation', 'Tractography', 'Neurofeedback', 
                      'Capsule endoscopy', 'Minimally invasive spine surgery', 'Elastography', 
                      'X-ray microtomography', 'Cone beam computed tomography', 'Optical tomography', 
                      'Radiosurgery', 'Computer-assisted surgery', 'Image-guided surgery', 'Artificial cell', 
                      'Decellularization', 'Cell sorting', 'Mass cytometry', 'Targeted drug delivery', 
                      'High-throughput screening', 'Molecular breeding', 'Genome editing', 'Gene delivery', 
                      'Synthetic genomics', 'DNA synthesis', 'Nanopore sequencing', 'Single cell sequencing', 
                      'Artificial photosynthesis', 'Gas separation', 'Nanofiltration']
print (len(biotechnology_list))

converging_tech_list = ['3D printing', 'Augmented reality', 'Virtual reality', 'Assistive technology', 
                        'Wearable technology', 'Microgeneration', 'Microgrid', 'Smart grid', 'Photovoltaics', 
                        'Grid energy storage', 'Energy storage', 'Wave power', 'Robotics', 
                        'Autonomous car', 'Extended reality', 'Computer-aided technologies', 'Digital mapping', 
                        'Visual computing', 'Image fusion', 'Digital image processing', 'Machine perception', 
                        'Genetic algorithm', 'Geometry processing', 'Reversible computing', 'Marine energy', 
                        'Data fusion', 'Soft robotics', 'Robotic process automation', 'Mixed reality', 
                        'Autonomous robot', 'Smart meter', 'Video processing', 'Machine vision', 'Mobile robot', 
                        'Humanoid robot', 'Unconventional computing', 'Robotic materials', 'Swarm robotics', 
                        'Mechatronics', 'Soft computing', 'Legged robot', 'Extreme learning machine', 
                        'Uncertainty quantification', 'Robot navigation', 'Markov chain Monte Carlo', 
                        'Automated machine learning', 'Constrained optimization', 'Evolutionary algorithm', 
                        'Robot learning', 'Medical image computing', 'Natural computing', 'Social robot', 
                        'Array processing', 'Soft sensor', 'Digital architecture', 'Quantum machine learning',
                        'Statistical signal processing', 'Urban computing', 'Telerobotics', 
                        'Support vector machine', 'Physical computing', 'Bio-inspired computing', 
                        'Sensor fusion', 'Robot control', 'Digital soil mapping', 'Concentrated solar power', 
                        'Computational imaging', 'Evolvable hardware', 'Computerized adaptive testing', 
                        'Optical neural network', 'Advanced process control', 'Telepresence', 
                        'Mobile mapping', 'Real-time simulation', 'Adaptive filter', 'Image registration', 
                        'Content-based image retrieval', 'Generative adversarial network', 'Visual odometry', 
                        'Structure from motion', 'Point cloud', 'E-textiles', 'Immersive technology', 
                        'Driving simulator', 'Gesture recognition', 'Active vision', 'Object detection', 
                        'Face detection', '3D reconstruction', 'Light field', 'Automatic differentiation', 
                        'Lidar', 'Vehicle-to-grid', 'Visual servoing', 'Teleoperation', 'Real-time MRI', 
                        'Reverse image search', 'Hands-free computing', 'Animated mapping', 
                        'Probabilistic roadmap']
print (len(converging_tech_list))

data_analytics_list = ['Speech recognition', 'Semantic search', 'Blockchain', 'Cloud robotics', 'Knowledge Graph', 
                       'Smart contract', 'Neural machine translation', 'Complex event processing', 
                       'Distributed ledger', 'Cyber-physical system', 'Statistical machine translation', 
                       'Knowledge extraction', 'Artificial neural network', 'TensorFlow', 'OpenCV', 
                       'Convolutional neural network', 'Chatbot', 'Activity recognition', 'Machine translation', 
                       'Language identification', 'Speech synthesis', 'Language model', 'Deep learning',
                       'Natural language understanding', 'Information extraction', 'Ontology learning', 
                       'Natural language generation', 'Automatic summarization', 'Learning to rank', 
                       'Question answering', 'Web mining', 'Plagiarism detection', 'Entity linking', 
                       'Social media mining', 'Decision support system', 'Web intelligence', 
                       'Information integration', 'Text mining', 'DSpace', 'Dialog system', 
                       'Multimodal interaction', 'Hypertext', 'Process mining', 'Accounting information system', 
                       'Data extraction', 'Automated reasoning', 'Runtime verification', 'Formal verification', 
                       'Language-based security', 'Multi-agent system', 'Computational intelligence', 
                       'Cognitive robotics', 'Cloud gaming', 'Marketing automation', 'Media intelligence', 
                       'Warehouse management system', 'Transportation management system', 
                       'Warehouse control system', 'Logistics automation', 'Business process automation', 
                       'Speaker diarisation', 'Language Weaver', 'Interactive machine translation', 
                       'Semantic compression', 'Lexical substitution', 'Natural Language Toolkit', 
                       'Textual entailment', 'Multi-document summarization', 
                       'Data mapping', 'Named graph', 'Digital prototyping', 'Automatic bug fixing', 
                       'General-purpose modeling', 'Cloud-based integration', 'Data virtualization', 
                       'Pandoc', 'Ω-automaton', 'Abstract semantic graph', 'Intelligent decision support system', 
                       'Cloud collaboration', 'Multi-model database', 'General-purpose language', 
                       'Component-based usability testing', 'Augmented cognition', 'Attentive user interface', 
                       'Helmholtz machine', 'Liquid state machine', 'Neural Turing machine', 
                       'Reliability block diagram', 'Transfer-based machine translation', 
                       'Controlled natural language', 'Deep linguistic processing', 'Software intelligence', 
                       'Time-utility function', 'Schema evolution', 'Operational intelligence', 
                       'Autonomous agent', 'Procedural reasoning system', 
                       'Belief–desire–intention software model', 'Knowledge Query and Manipulation Language']
print (len(data_analytics_list))

health_medical_list = ['Virtual patient', 'Medical device', 'Algorithmic trading', 'High-frequency trading', 
                       'Health informatics', 'Connected health', 'Health technology', 'Digital phenotyping', 
                       'MHealth', 'Imaging informatics', 'EHealth', 'Telemedicine', 'Persuasive technology', 
                       'Educational technology', 'Telerehabilitation', 'Telehealth', 'Remote patient monitoring', 
                       'Artificial intelligence in healthcare', 'Process analytical technology', 
                       'Electronic communication network', 'Automated trading system', 'Weak AI', 
                       'Medical algorithm', 'Gustatory technology', 'Hypothetical technology', 'Social machine', 
                       'Patent visualisation', 'Human-based computation', 'AutoTutor', 'Coh-Metrix', 
                       'Medical logic module', 'Ultra-low latency direct market access', 'Cognitive tutor', 
                       'Energy Systems Language', 'Non-native speech database', 'ACT-R', 
                       'Future Attribute Screening Technology', 'Auction sniping', 'Social trading', 
                       'Herrmann Brain Dominance Instrument', 'SOAP note', 'Virtual world language learning', 
                       'Index arbitrage', 'Validation (drug manufacture)', 'Trading strategy', 
                       'Clinical documentation improvement', 'Biocommunication (science)', 
                       'Direct-access trading', 'NHS Connecting for Health', 'Continua Health Alliance',
                       'Forensic video analysis', 'Automated dispensing cabinet', 'Compulsion loop', 
                       'Biopsychosocial model', 'Offender Assessment System', 
                       'Medical toxicology', 'Knowledge transfer', 'Human-centered computing',
                       'Digital labor', 'Global mental health', 'Software studies', 'Knowledge translation',
                       'Computerized physician order entry', 'Digital literacy', 'Choose and Book', 
                       'Health literacy', 'Direct market access', 'Aerospace Valley', 
                       'Foreign exchange aggregator', 'Health care analytics', 'Decision aids',
                       'Telepathology', 'Chronic care management', 'Electronic data capture', 
                       'Consumer-driven healthcare', 'Electronic prescribing', 'Teledermatology',
                       'Home automation for the elderly and disabled', 'Medical billing', 
                       'Computer-supported collaboration', 'Simulated patient', 'Retail foreign exchange trading', 
                       'General purpose technology', 'Remote surgery', 'Enterprise master patient index', 
                       'Clinical data management', 'Remote therapy', 'Process validation', 'Brain fingerprinting', 
                       'Cross Enterprise Document Sharing', 'Digital collaboration', 'Laboratory informatics', 
                       'Speech translation', 'Point of care', 'Electronic Broking Services', 
                       'M-learning', 'Telecare', 'Pharmacy automation', 
                       'Information and communications technology', 'Cyberpsychology']
print (len(health_medical_list))

network_list = ['5G', 'Unified communications', 'Financial technology', 'Local positioning system',
                'Homomorphic encryption', 'Identity management', 'Computer security', 'Virtual assistant',
                'Grid computing', 'Network virtualization', 'Digital security', 'Post-quantum cryptography',
                'Network function virtualization', 'Trusted Computing', 'Energy harvesting', 
                'Software-defined networking', 'Building automation', 'Stream processing', 'Mobile computing', 
                'Embedded software', 'Digital electronics', 'Home automation', 'Wireless network', 
                'Semiconductor memory', 'Laser scanning', 'Wireless sensor network', 'Hardware security', 
                'Heterogeneous computing', 'Stochastic computing', 'Mobile cloud computing', 
                'Information-centric networking', 'Exascale computing', 'Terabit Ethernet',
                'Low-power electronics', 'Time-Sensitive Networking', 'Wireless mesh network', 
                'Reconfigurable computing', 'Routing protocol', 'Ad hoc network', 'Cellular network', 
                'Mobility management', 'Optical interconnect', 'Maglev', 'VLSI Technology', 'Circuit design', 
                'Functional verification', 'Secure multi-party computation', 'Privacy-enhancing technologies', 
                'Network security', 'Processor design', 'Mobile technology', 'Edge device', 
                'Synchronous Ethernet', 'Backbone network', 'Data transmission', 'Contactless payment',
                'Telecommunications Management Network', 'Roofnet', 'Common-channel signaling', 
                'Multicast encryption', 'Network mapping', 'Ultra-wideband', 'Digital AMPS', 
                'Satellite constellation', 'Fixed–mobile convergence', 'ControlNet', 'Consumer IR', 
                'Data cable', 'Cable management', 'Unified Payments Interface', 
                'Remote deposit', 'MobilePay', 'Virtual advertising', 'Barcode printer', 
                'Resolution enhancement technology', 'Under vehicle inspection', 'Intelligent speed adaptation', 
                'Automatic number-plate recognition', 'Analogue electronics', 'Semiconductor process simulation', 
                'PLECS', 'Quite Universal Circuit Simulator', 'End-to-end encryption', 'Verifiable computing', 
                'Authenticated encryption', 'File integrity monitoring', 'Dynamic recompilation', 
                'Vision processing unit', 'Speculative multithreading', 'Fabric computing', 
                'High-throughput computing', 'Mobile wireless sensor network', 'Positioning system', 
                'Optical mesh network', 'Point-to-multipoint communication', 'Super Wi-Fi', 'Network tomography', 
                'Contact image sensor', 'Tiled rendering', 'Smart thermostat']
print (len(network_list))

nanotech_list = ['Quantum sensor', 'Optical computing', 'Quantum computing', 'Smart material', 
                 'Quantum information science', 'Photoelectrochemistry', 'Computational electromagnetics', 
                 'Electrospinning', 'Pulsed laser deposition', 'Laser cooling', 'Nanoelectronics', 
                 'Strain engineering', 'Electronic skin', 'Thermoelectric generator', 'Laser beam welding', 
                 'Electron tomography', 'Electronic nose', 'Failure analysis', 'Semiconductor', 
                 'Optoelectronics', 'Photonics', 'Quantum key distribution', 'Flexible electronics', 
                 'Quantum algorithm', 'Electrowetting', 'Electronic packaging', 'Printed electronics', 
                 'Scanning transmission electron microscopy', 'Free-electron laser', 'Quantum imaging',
                 'Photonic integrated circuit', 'Electroactive polymers', 'Quantum cryptography', 
                 'Selective laser sintering', 'Electron spectroscopy', 'Digital microfluidics', 
                 'Electron energy loss spectroscopy', 'Molecular electronics', 'Plasma processing', 
                 'Quantum error correction', 'Nanosensor', 'Plasma electrolytic oxidation', 'Ghost imaging', 
                 'Mass spectrometry imaging', 'Dielectrophoresis', 'Organic electronics', 
                 'Selective laser melting', 'Capacitive deionization', 'Microwave chemistry', 'Nanofluidics', 
                 'Soft lithography', 'Surface plasmon resonance', 'Rapid prototyping', 'Thermal barrier coating', 
                 'Magnetic refrigeration', 'Spintronics', 'Micromagnetics', 'Computational lithography', 
                 'Photolithography', 'Nanoimprint lithography', 'Microfabrication', 'Photon upconversion', 
                 'Ion beam', 'Photocatalysis', 'Plasma polymerization', 'Plasma etching', 
                 'Chemical vapor deposition', 'Ion implantation', 'Epitaxy', 'Atomic layer deposition', 
                 'Piezotronics', 'Computational magnetohydrodynamics', 'Hamiltonian optics', 
                 '5D optical data storage', 'Thermal management (electronics)', 'Thick-film technology', 
                 'Electron-beam technology', 'Thermophotovoltaic', 'NASA spinoff technologies', 
                 'Quantum dot display', 'Rapid thermal processing', 'Heat-assisted magnetic recording', 
                 'Molecular scale electronics', 'Reverberation mapping', 'Continuous ink system', 
                 'Through-silicon via', 'Metamaterial cloaking', 'Nanocircuitry', 'Quantum technology', 
                 'Laser-hybrid welding', 'Superconducting quantum computing', 'Quantum network', 
                 'Nanolaser', 'Nanowire battery', 'One-way quantum computer', 'Ultramicroelectrode', 
                 'Quantum simulator', 'Spin transistor', 'Next-generation lithography', 'Nanogenerator']
print (len(nanotech_list))
df_tech_checked = pd.DataFrame(autonomous_tech_list + biotechnology_list + converging_tech_list + data_analytics_list + health_medical_list + network_list + nanotech_list, columns = ['Wiki_Entity'])

non_tech_list = ['IEEE Industrial Electronics Society', 'Cyborg anthropology', 'Radical Evolution', 
                 "Moore's law", 'Ephemeralization', 'Democratic rationalization', 'R&D management', 
                 'Outline of transhumanism', 'Outline of artificial intelligence', 'Antifragility',
                 'Conceptual dependency theory', 'Centre for the Study of Existential Risk', 'Blocks world', 
                 'Knowledge level modeling', 'Instrumental convergence', 'Timeline of machine learning', 
                 'Global value chain', 'Daniel Crevier', 'Leslie P. Kaelbling', 'Julian Savulescu', 
                 'Transhumanist politics', 'Pioneer Award in Nanotechnology', 'Race Against the Machine', 
                 'Large technical system', 'Colors of biotechnology', 'Preorder economy', 'Rhon psion', 
                 'Qualification problem', 'Machine Intelligence Research Institute', 'Organisational semiotics', 
                 'Superintelligence: Paths, Dangers, Strategies', 'Outline of thought', 'Bioconservatism', 
                 'Mimetic isomorphism', 'Specialization of knowledge', 'Program derivation', 'Manu Prakash', 
                 'European Network for Health Technology Assessment', 'Andrew Barto', 'Extropianism', 
                 'Attention schema theory', 'Product lifecycle', 'Singularitarianism', 'No-hiding theorem', 
                 'Techno-progressivism', 'Waterloo Institute for Nanotechnology', 'Virtual Health Library', 
                 'Evolving the Alien', 'Postanalytic philosophy', 'Qualitative research', 'Coherentism', 
                 'International Council on Nanotechnology', 'Alphabet of human thought', 'Randal A. Koene', 
                 'Martha E. Pollack', 'Posthumanism', 'Innovacorp', 'Technology acceptance model', 
                 'Medical cybernetics', 'Sociotechnical system', 'Energy cannibalism', 'Oxygen cycle', 
                 'ADDIE Model', 'Technological singularity', 'George A. Bekey', 'Sensitivity auditing', 
                 'Timeline of artificial intelligence', 'The Nexus Trilogy', 'Center for Open Science', 
                 'Control theory', 'E-social science', 'Mathematical physiology', 'The Astonishing Hypothesis', 
                 'IEEE Cledo Brunetti Award', 'Domain knowledge', 'CogPrints', 'Patrick Winston', 
                 'Journal of Knowledge Management Practice', 'Blue Ocean Strategy', 'Technocentrism', 
                 'Quasi-empirical method', 'Script theory', 'Digital sociology', 'Unorganisation', 
                 'Psychophysical parallelism', 'Critical Gameplay', 'Dispersed knowledge', 'Pattern theory', 
                 'Logic form', 'Helen Nissenbaum', 'Algorithmic learning theory', 'Norio Taniguchi', 
                 'Flash lag illusion', 'Non-spiking neuron', 'Rationality and Power', 'Digital philosophy', 
                 'Decoy effect', 'Computing Community Consortium', 'Discrete system', 'No Silver Bullet', 
                 'Experimental Mechanics', 'Eclipse Trilogy', 'Generativity', 'AI takeover', 'Equator IRC', 
                 'Yseop', 'Cluster Innovation Centre', 'Ramification problem', 'Mathematical theory', 
                 'Actor–network theory', 'Hybrid logic', 'Naturalized epistemology', 'Hava Siegelmann', 
                 'Minatec', 'Telecommunications forecasting', 'Logical reasoning', 'Crossing the Chasm', 
                 'Formal Methods Europe', 'Marooned in Realtime', 'Ringelmann effect', 'Binding problem', 
                 'Psycoloquy', 'Storyspace', 'Computational scientist', 'Social translucence', 'Naïve realism', 
                 'Efficient coding hypothesis', 'COSMOS cohort study', 'Critical design', 'Recursion (novel)', 
                 'Metabolite damage', 'Bicycle tree', 'Autogenic succession', 'Autopoiesis', 'Compatibilism', 
                 'Carbon cycle re-balancing', 'Greenhouse gas emissions accounting', 'Extended mind thesis', 
                 'Correspondence problem', 'Effective altruism', 'Chemoaffinity hypothesis', 'Inclusive business', 
                 'Superdeterminism', 'Directed panspermia', 'Post-convergent', 'Andrew Ng', 'Bin packing problem', 
                 'Preferential looking', 'Bias–variance tradeoff', 'Eliminative materialism', "Conway's law", 
                 'NASA Advanced Space Transportation Program', 'Homayoon Kazerooni', 'Cognitivism (psychology)', 
                 'Universal approximation theorem', 'Technological utopianism', 'Glossary of robotics', 
                 'Kestrel Institute', 'Start-Up Chile', 'Safety property', 'Quantum Aspects of Life', 
                 'Rhythmanalysis', 'Global Environment for Network Innovations', 'Duration calculus', 
                 'Cosmic microwave background', 'Extended cognition', 'High-level equilibrium trap', 
                 'Unruh effect', '10/90 gap', 'Event reconstruction', 'Opportunity management', 
                 'Reactome', 'Shiv Nadar University', 'World disclosure', 'IJCAI Computers and Thought Award', 
                 'Weak ontology', 'Theory-ladenness', 'Bright green environmentalism', 'Specific surface energy', 
                 'Manteia Predictive Medicine', 'Lévy flight foraging hypothesis', 'Connectivism', 
                 'Business interoperability interface', 'Timeline of computing hardware before 1950', 
                 'Bounded rationality', 'Fairphone', 'List of omics topics in biology', 'Yaniv Altshuler', 
                 'Correlates of War', 'Ford Airstream', 'Nonequilibrium Gas and Plasma Dynamics Laboratory', 
                 'The Tech Awards', 'Lighthill report', 'Manchester Institute of Innovation Research', 
                 'Conversation theory', 'Space Studies Institute', "Brooks's law", 'Barcan formula', 
                 'Center for Sustainable Global Enterprise', 'Language Technologies Institute', 
                 'Tampere University of Technology', 'The Age of Spiritual Machines', 'Consumer privacy', 
                 'Science policy', 'Timeline of carbon nanotubes', 'Outline of philosophy', 'Gingivoplasty', 
                 'European Neural Network Society', 'Poverty of the stimulus', 'CPM-GOMS', 'Peter Kyberd', 
                 'Boundary object', 'Vega Science Trust', 'Resource Extraction Monitoring', 'Coherent addition', 
                 "Building Harlequin's Moon", 'Centre for Development of Advanced Computing', 
                 'Biological naturalism', 'Virginia Smart Road', '19th-century turnpikes in Massachusetts', 
                 '2009 Southeast Asian haze', 'A New Deal for Transport: Better for everyone', 
                 'Abstract particulars', 'Actuarial Society of South Africa', 'Adhimoksha', 'CONWIP', 
                 'Aggressiveness strategy', 'Alberta Council on Admissions and Transfer', 'Ali Malkawi', 
                 'Ama (ayurveda)', 'Glossary of artificial intelligence', 'Gellish English dictionary', 
                 'Anaerobic contact process', 'Analytical phonics', 'Anatman (Hinduism)', 'Netcode', 
                 'Ancient Commentators on Aristotle project', 'Aptivate', 'Arctic Research Foundation', 
                 'Arthropod gap', 'Artificial intelligence, situated approach', 'Full-spectrum dominance', 
                 'Association of Independent Professionals and the Self-Employed', 'Inductive reasoning aptitude', 
                 'Astrobiology Society of Britain', 'AttentionTracking', 'Attributable risk percent', 
                 'Attrition (medicine, epidemiology)', 'Australian Psychology Accreditation Council', 
                 "Backing Australia's Ability", 'Hawking radiation', 'Gates Computer Science Building, Stanford', 
                 'Bangladesh Institute of Peace & Security Studies', 'Basal (medicine)', 'BCS-FACS', 
                 'Best of Biotech', 'Bikeway safety', 'Binding neuron', 'Boreal Forest Conservation Framework', 
                 'Bornhuetter-Ferguson method', 'Brace matching', 'Bridge program (higher education)', 
                 'Brittle Books Program', 'Bumblebee models', "Busemann's Biplane", 'Social genome', 
                 'Canada Education Savings Grant', 'Mathematical universe hypothesis', 
                 'Canada Social Transfer', 'Canadian Power and Sail Squadrons', 'Capital Jury Project', 
                 'CAPRISA 004', 'CARINE', 'Epistemological solipsism', 'NeuroRacer', 'Strategic foresight', 
                 'CDM Gold Standard', 'Centauro event', 'Glossary of mechanical engineering', 
                 'Center for BrainHealth', 'Center for Regulatory Effectiveness', 'Knowledge mobilization', 
                 'Centre for Military and Strategic Studies', 'Combinatorial explosion', 'Syntheism', 
                 'Centre for Philosophy of Natural and Social Science', 'Certificate of Sixth Year Studies', 
                 'Certified Protection Officer', 'China Open Resources for Education', 'CR Society International', 
                 'Crosby–Kugler capsule', 'DASH7 Alliance', 'Aramis, or the Love of Technology', 
                 'Defence Centre of Training Support', 'Defence Industrial Strategy', 'Maximum subarray problem', 
                 'Defense Centers of Excellence for Psychological Health and Traumatic Brain Injury', 
                 'Designs of the Time', 'Computer Networks (journal)', 'Canadian Biodiversity Strategy', 
                 'Division of Acquired Immunodeficiency Syndrome', 'Ecological inheritance', 'Economic puzzle', 
                 'Economy-wide material flow accounts', 'Embodied bilingual language', 'State consequentialism', 
                 'Empirical limits in science', 'Environment Conservation Group', 'European Employment Strategy', 
                 'European Group on Tort Law', 'European Internet Accessibility Observatory', 
                 'European Land-Robot Trial', 'European Privacy Association', 'Event-related optical signal', 
                 'Ex parte Lundgren', 'Excellence in Cities', 'Expected transmission count', 'Explorer AUV', 
                 'Face Animation Parameter', 'The Lean Startup', '2045 Initiative', 
                 'Federal Networking Council', 'Ferroelectric polymers', 'FFAG accelerator', 
                 'Five Year Forward View', 'Fraud-on-the-market theory', 'Fredkin finite nature hypothesis', 
                 'Future map (organizational planning)', 'Garib Sena', 'Glob (visual system)', 
                 'Great Trade Collapse', 'Groupe INTRA', 'Hackers.mu', 'Technological change', 
                 'Health Impact Fund', "Healthcare Businesswomen's Association", 'ISTE Standards', 
                 'Humanitarian Response Index', 'ICL Direct Machine Environment', 'Agile software development', 
                 'Institute for 21st Century Agoras', 'Communicating sequential processes', 
                 'Institute for Healthcare Improvement', 'Institute for Learning and Teaching in Higher Education',
                 'International Assessment of Agricultural Knowledge, Science and Technology for Development', 
                 'International Society for NeuroVirology', 'International Society for Pharmaceutical Engineering', 
                 'International Virtual Observatory Alliance', 'Internet Universality', 'Algorithmic skeleton', 
                 'Investor Network on Climate Risk', 'Ionian Enlightenment', 'Human action cycle', 
                 'Jerome C. Hunsaker Visiting Professor of Aerospace Systems', 'Jesse Fried', 'Jiangbeizui CBD', 
                 'Joint Capabilities Integration Development System', 'Joint Mathematical Council', 
                 "Kirk's Fire Investigation", 'KISKA', 'Knowledge Systems Laboratory', 'Switching lemma', 
                 'Language/action perspective', 'Lemur Project', 'Dematerialization (economics)', 
                 'Marine energy management', 'Materials system', 'Media Key Block', 
                 'Medical Practitioners Disciplinary Tribunal', 'Meyerhoff Scholarship Program', 
                 'Michigan Aeronautical Research Center', 'Mike & Ophelia Lazaridis Quantum-Nano Centre', 
                 'Mimas (data centre)', 'Modalities (sociology)', 'MOF Model to Text Transformation Language', 
                 'Moire deflectometry', 'Mortality Medical Data System', 'Network economics', 
                 'MTA SZTAKI Laboratory of Parallel and Distributed Systems', 'MVEDR', 
                 'Napier Oryx', 'National Assessment Bank', 'National Exposure Research Laboratory', 
                 'National Institute for Computational Sciences', 'National Key Disciplines', 
                 'National Livestock Identification System', 'Optics and Photonics News', 'Effortfulness', 
                 'National Resource Center for Health Information Technology', 'Nature Society (Singapore)', 
                 'Neglected tropical disease research and development', 'New Approach to Appraisal', 
                 "New Partnership for Africa's Development E-School Program", 'New security concept', 
                 'Nonlinear pricing', 'North American Native Fishes Association', 'North East Humanists', 
                 'North Sea Region Programme', 'Nuker Team', 'NYU Stern Center for Business and Human Rights', 
                 'Observations of daily living', 'Oil imperialism theories', 'OpenVPX', 'Availability heuristic', 
                 'Pacific Ocean Shelf Tracking Project', 'Planetary phase of civilization', 'Plekton', 
                 'Plug-in Hybrid Electric Vehicle Research Center', 'Post-Critical', 'Precipitationshed', 
                 'Primal Integration', 'Principles of European Tort Law', 'Prony equation', 'Informatics Forum', 
                 'Psychology of previous investment', 'Public participation geographic information system', 
                 'Purity (gas)', 'Quantity adjustment', 'Real Time Information Group', "Koomey's law", 
                 'Recursive competitive equilibrium', 'Regenerative Medicine Partnership in Education', 
                 'Registered Science Technician', 'Registered Scientist', 'Problem solving environment', 
                 'Responsible autonomy', 'Reuters Digital Vision Program', 'Riversimple Urban Car', 
                 'San Francisco Ethics Commission', 'School of Literature, Media, and Communication', 
                 'SCRIPT (AHRC Centre)', 'Sectoral currency', 'Segal Design Institute', 'Sensation (fiction)', 
                 'SIEPAC', 'Situational analysis', 'Slipstream (science fiction)', 'Technology policy', 
                 'Sociology of valuation', 'Soft energy technology', 'Duration (philosophy)', 
                 'Software release train', 'Species pool', 'Institute of Technology, Guru Ghasidas University', 
                 'Start Input/Output', 'Swarm Development Group', 'Foresight (futures studies journal)', 
                 'Talking tactile tablet', 'Tamil Nadu Science Forum', 'Tarner Lectures', 'Tattvasamgraha', 
                 'Tensor product model transformation', 'The British Vacuum Council', 'Tieline', 
                 'Tools and Trades History Society', 'Transaction Workflow Innovation Standards Team', 
                 'Trigger (particle physics)', 'Triune continuum paradigm', 'Tucson Amateur Packet Radio', 
                 'Tufts OpenCourseWare', 'Tweel (A Martian Odyssey)', "Kerner's breakdown minimization principle", 
                 'U.S. Commission on National Security/21st Century', 'UNESCO Science Report', 
                 'United Kingdom Accreditation Forum', 'Universities Funding Council', 'Customer data platform', 
                 'University Professors Program', 'Wired for Management', 'Wolf effect', 'Wuxi New Area', 
                 'Y Chromosome Consortium', 'Z User Group', 'Zoom creep', 'Imponderable fluid', 
                 'Problem of mental causation', 'Labshare', 'Quantum Philosophy', 'Subvocalization', 
                 'Internet research ethics', 'Bradford Hill criteria', 'Call2Recycle', 'Biotechnology consulting', 
                 'Flexible purpose corporation', 'Comprehensive National Power', 'D20 Future', 'OScar', 
                 'Socio-ecological system', 'Basel Declaration', 'Sogeti', 'Safehold', 'Max More', 
                 'European Schoolnet', 'Harebrained Schemes', 'Network Centric Operations Industry Consortium', 
                 'Learning-by-doing (economics)', 'Haddon Matrix', 'IEEE Frank Rosenblatt Award', 
                 'Glossary of electrical and electronics engineering', 'The Transhumanist Wager', 
                 'Strategic human resource planning', 'Population process', 'Attention economy', 
                 'Innovation economics', 'Open research', 'Hypercar (concept car)', 'Heuristic evaluation', 
                 'Constructivism (philosophy of education)', 'Preference utilitarianism', 'ISO 10006', 
                 'Algorithmic bias', 'Bibliographic coupling', 'Task Force Scorpio', 'Neocatastrophism', 
                 "Bremermann's limit", 'Crysis 3', 'CMBFAST', 'Keratoprosthesis', 'Technogaianism', 
                 'Advanced Extension Award', 'Grounded theory', 'Mind–body dualism', 
                 'Contrast transfer function', 'Outline of computer engineering', 'Human Speechome Project', 
                 'Service management', 'McCumber relation', 'Free energy principle', 'Complex system', 
                 'Valiant–Vazirani theorem', 'Intergalactic Computer Network', 'List of electrical engineers', 
                 'IEEE Robotics and Automation Award', 'Collaborative information seeking', 
                 'Cartesian materialism', 'Solution architect', 'Richard S. Sutton', 
                 'NIOSH Power Tools Database', 'Biosocial theory', 'Comparison of Java and C++', 'Food Race', 
                 'Kano model', 'System Rush', 'Prato reaction', 'Cartesianism', "Ohm's acoustic law", 
                 'Peer-to-peer renting', 'Young–Helmholtz theory', 'Sensory nervous system', 'J. Anthony Movshon', 
                 'World Usability Day', 'Enumerative induction', 'Rigi (software)', 'Discourse on the Method', 
                 'Theory of everything (philosophy)', 'Multiple drafts model', 'Oxford Martin School', 
                 'Planned obsolescence', 'Knowledge gap hypothesis', 'Sentiocentrism', 
                 'Knowledge management', 'Lego Serious Play', 'Energy policy of India', 
                 'Launch and Early Orbit phase', 'Information Systems Professional', 
                 'International Symposium on Wearable Computers', 'Eudoxa', 'Mark Alan Walker', 
                 'Lib Sh', 'Boolean Pythagorean triples problem', 'Drake equation', 'Philosophical skepticism', 
                 'Indore Bus Rapid Transit System', 'OODA loop', 'CourseSmart', "Gabbay's separation theorem", 
                 'Before You Know It (software)', 'Kardashev scale', 'Boltzmann brain', 'EQ-5D', 
                 'Abundance: The Future Is Better Than You Think', 'Kaya identity', 'Counterfactual definiteness', 
                 'Rabies immunoglobulin', 'Anekantavada', 'Chemical specificity', 'Mathematicism', 
                 'Greenhouse debt', 'Feature-driven development', 'Programming Research Group', 'P3M', 
                 'Indigo Line', 'Preformationism', 'Social intuitionism', 'Benefits realisation management', 
                 'Findability', 'Fermi paradox', 'IEEE Power & Energy Society', 'CCIE Certification', 
                 'Physics envy', 'Hockney–Falco thesis', 'DRDO Self Propelled Mine Burier', 'Truth-value link', 
                 'Manufacturing Advisory Service', 'Zombies, Run!', 'Meta Content Framework', 'JumpStartFund', 
                 'Decorrelation theory', 'Epistemological pluralism', 'Kuramoto model', 'STRIDE (security)', 
                 'Global Telecoms Exploitation', 'Weak central coherence theory', 'Hornby Virtual Railway', 
                 'Market for zero-day exploits', 'No-communication theorem', 'The Design of Business', 
                 'Highly optimized tolerance', 'Libidinal Economy', 'IB Group 4 subjects', 
                 'Quantum entanglement', 'Cosmic string', 'Speculative evolution', 'Logicism', 
                 'Von Neumann–Wigner interpretation', 'Anomalous monism', 'Speculative damages', 
                 'RIKEN Quantitative Biology Center', 'Terasem Movement', 'Graph edit distance', 
                 'Napierian logarithm', 'U15 Group of Canadian Research Universities', 'User error', 
                 'Borwein integral', 'Jurassic World Evolution', 'Technics and Civilization', 
                 'Sequence space (evolution)', 'Mars Gravity Biosatellite', 'Theory-theory', 'Transhumanism', 
                 'Institute for the Encouragement of Scientific Research and Innovation of Brussels', 
                 'Cyberfeminism', 'Cuspy halo problem', 'Knowledge building', 'RV Investigator', 
                 "Hamilton's principle", 'Database of Molecular Motions', 'Functional management',
                 'Formative context', 'Turing completeness', 'Landes Bioscience', 'Zero-player game', 
                 'International Classification for Standards', 'The Doug Engelbart Institute', 
                 'Department of Essential Drugs and Medicines', 'Wheeler–Feynman absorber theory', 
                 'System of concepts to support continuity of care', 'Deployable Virtual Training Environment', 
                 'TrackIR', 'UML Partners', 'Extracellular field potential', 'H-Bio', 'Biological system',
                 'Ghirardi–Rimini–Weber theory', 'Patent privateer', 'Murray Shanahan', 
                 'Decision field theory', 'Europarl Corpus', 'Mental process', 'Foresight Institute', 
                 'Stimulus–response model', 'Negation normal form', 'Eco-investing', 'DeepCwind Consortium', 
                 'Mondex', 'Simulation hypothesis', 'Data activism', 'Chain fountain', 'Corpuscularianism', 
                 'Cognitive map', 'Immerman–Szelepcsényi theorem', 'EUREL', '2000s in science and technology', 
                 'Core competency', 'Moralistic fallacy', 'Gene structure', 'Commonwealth Saga', 
                 'Integrated Architecture Framework', 'S2P (complexity)', 'Nematicon', 'The Blue Economy', 
                 'Scale-space segmentation', 'Euromatrix', 'Resource productivity', 'COSTART', 'Reference beam', 
                 'Church–Turing thesis', 'Analytic–synthetic distinction', 'A3 problem solving', 
                 'Society for the Study of Artificial Intelligence and the Simulation of Behaviour']
print (len(non_tech_list))
df_non_tech_checked = pd.DataFrame(non_tech_list, columns = ['Wiki_Entity'])

df_tech_checked['Target'] = 1
df_non_tech_checked['Target'] = 0

df_50k_vec = pd.read_csv('Datasets/Original_ET50k_entity_vectors.csv')
df_50k_vec = df_50k_vec.rename(columns = {'Unnamed: 0':'Wiki_Entity'})
df_classifier_input = pd.concat([df_tech_checked[['Wiki_Entity','Target']], df_non_tech_checked[['Wiki_Entity','Target']]])
df_classifier_input = df_classifier_input.merge(df_50k_vec, how = 'left', left_on = 'Wiki_Entity', right_on = 'Wiki_Entity')
# print (df_non_tech_checked['Wiki_Entity'].value_counts().head(10))
# df_classifier_input[df_classifier_input['Feature 1'].isna()]
df_classifier_input.to_csv('Datasets/Tech_Classifier_Input_Data.csv', index = False)
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 700

# %%
df_50k_vec = pd.read_csv('Datasets/Original_ET50k_entity_vectors.csv')
df_50k_vec.rename(columns = {'Unnamed: 0':'Wiki_Entity'}, inplace = True)
df_50k_vec = df_50k_vec.set_index('Wiki_Entity')

# %%
df_50k_vec
# Out:
#                                         Feature 1  Feature 2  Feature 3  \
# Wiki_Entity
# List of emerging technologies           -1.329528  -0.066357  -1.127888
# Machine guidance                        -0.099358  -0.085137  -0.464794
# Gustatory technology                    -0.155806   0.097487  -0.098125
# Differential technological development   0.160350  -0.037422  -0.752458
# Robotic paradigm                        -0.800612  -0.039436  -0.866630
# ...                                           ...        ...        ...
# Financial technology                    -0.924867  -0.213630  -0.861329
# Genetics                                 0.292666   0.592966   0.879762
# Microsatellite                          -1.223683   0.009714   1.241995
# Online service provider                 -0.677627   0.046853  -1.007655
# Research                                 0.046085   0.113145   0.802728
#
#                                         Feature 4  Feature 5  Feature 6  \
# Wiki_Entity
# ...

# %% [markdown]
# # XGBoost Classifier

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.metrics import accuracy_score, f1_score, fbeta_score, log_loss, roc_auc_score, confusion_matrix

# %%
# 30 different seeds
seed_list = [42, 123, 5581, 3501, 1911, 867, 88169, 445, 2594, 1278, 
             9579, 34262, 73159, 17074, 52689, 878269, 758, 43255, 471012, 805211, 
             409, 513235, 68393, 993313, 830895, 17036, 629905, 881, 5458219, 2639]

# Define parameter grid
param_grid = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.03, 0.05, 0.1],
    'max_depth': [3, 5, 7, 10],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.5, 0.8, 1.0],
    'lambda':[1.5, 2],
    'alpha':[1.5, 2]
}

# %%
# %%time

feature_list = df_classifier_input.columns.tolist()[2:]
target = 'Target'
X, y = df_classifier_input[feature_list], df_classifier_input[target]

seed_index = 0
row_list = []
while seed_index < len(seed_list):
    t_start = datetime.now()
    seed = seed_list[seed_index]
    print (seed)

    row_dict = {}
    row_dict['seed'] = seed

    # Input Data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

    # Model Training
    xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
    
    clf = RandomizedSearchCV(estimator=xgb_clf, 
                             param_distributions=param_grid,
                             scoring='accuracy', 
                             cv = 5,
                             n_iter=1000, 
                             n_jobs = -1,
                             verbose=1)
    clf.fit(X_train, y_train)

    best_model = clf.best_estimator_
    
    y_pred = best_model.predict(X_test)
    y_pred_log_proba = np.log(best_model.predict_proba(X_test))
    y_pred_proba = best_model.predict_proba(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')
    fbeta = fbeta_score(y_test, y_pred, average='weighted', beta=0.5)
    log_loss = log_loss(y_test, y_pred_log_proba, eps=1e-15)
    auc = roc_auc_score(y_test, y_pred_proba[:, 1])    

    row_dict['Accuracy'] = accuracy
    row_dict['F1_Score'] = f1
    row_dict['FBeta_Score'] = fbeta
    row_dict['Log_Loss'] = log_loss
    row_dict['AUC_Score'] = auc
    
    row_list.append(row_dict)

    seed_index = seed_index + 1
    t_end = datetime.now()
    print (t_end - t_start)
# Out:
# 42
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# /opt/anaconda3/envs/my_pymc_env/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# /opt/anaconda3/envs/my_pymc_env/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1766         evaluate_candidates(
#    1767             ParameterSampler(
# -> 1768                 self.param_distributions, self.n_iter, random_state=self.random_state
#    1769             )
#    1770         )
#
# ...

# %%
df_xgb_model_result = pd.read_csv('Tech_Detection_XGBoost_Classifier_Result.csv')
df_xgb_pred_result = pd.read_csv('Original_ET50k_Prediction.csv')

# %%
df_input_label_indices = pd.read_csv('Datasets/Cosmos_Dataset.csv')

# %%
df_input_label_indices.columns.tolist()
# Out:
# ['Wiki_Entity',
#  'ET3 meta-clusters',
#  'ET7 theme clusters',
#  'Pageviews_2019',
#  'Pageviews_2020',
#  'Pageviews_2021',
#  'Pageviews_2022',
#  'Pageviews_2023',
#  'Pageviews_3yr_slope',
#  '3yr_Awareness_Index',
#  'Pageviews_5yr_slope',
#  '5yr_Awareness_Index',
#  'Generality_Index',
#  'DeepTech_Index',
#  'Age_of_Tech_Index',
#  'TFR',
#  'Publication_Counts_2019',
#  'Publication_Counts_2020',
#  'Publication_Counts_2021',
#  'Publication_Counts_2022',
#  'Publication_Counts_2023',
#  'Publication_Counts_3yr_slope',
#  '3yr_Publications_Growth_Index',
#  'Publication_Counts_5yr_slope',
#  '5yr_Publications_Growth_Index',
#  'Google_Patent_Counts_2019',
#  'Google_Patent_Counts_2020',
#  'Google_Patent_Counts_2021',
#  'Google_Patent_Counts_2022',
#  'Google_Patent_Counts_2023',
#  'Google_Patent_Counts_3yr_slope',
#  '3yr_Google_Patent_Growth_Index',
#  'Google_Patent_Counts_5yr_slope',
#  '5yr_Google_Patent_Growth_Index',
#  'First_Pub_Year',
#  'GS_Author_Counts',
# ...

# %%
df_50k_features = df_input_label_indices[['Wiki_Entity', 'ET3 meta-clusters', 'ET7 theme clusters', 
                                          'Pageviews_2019', 'Pageviews_2020', 'Pageviews_2021', 'Pageviews_2022',
                                          'Pageviews_2023', 'Pageviews_3yr_slope', '3yr_Awareness_Index',
                                          'Pageviews_5yr_slope', '5yr_Awareness_Index', 'Generality_Index',
                                          'DeepTech_Index', 'Age_of_Tech_Index', 'TFR', 'Publication_Counts_2019',
                                          'Publication_Counts_2020', 'Publication_Counts_2021',
                                          'Publication_Counts_2022', 'Publication_Counts_2023',
                                          'Publication_Counts_3yr_slope', '3yr_Publications_Growth_Index',
                                          'Publication_Counts_5yr_slope', '5yr_Publications_Growth_Index',
                                          'Google_Patent_Counts_2019', 'Google_Patent_Counts_2020',
                                          'Google_Patent_Counts_2021', 'Google_Patent_Counts_2022',
                                          'Google_Patent_Counts_2023', 'Google_Patent_Counts_3yr_slope',
                                          '3yr_Google_Patent_Growth_Index', 'Google_Patent_Counts_5yr_slope',
                                          '5yr_Google_Patent_Growth_Index', 'First_Pub_Year', 'GS_Author_Counts',
                                          'GS_Author_Counts_Scaled', 'Wikipedia_External_Links',
                                          'Wikipedia_Num_Ref_Links', 'Wikipedia_Coordinates',
                                          'Wikipedia_Num_Language', 'ET100_Flag']]

df_pred_comb = df_xgb_pred_result[['Wiki_Entity', 'Predicted_Label', 'Predicted_Prob']].merge(df_50k_features, how = 'left', left_on = 'Wiki_Entity', right_on = 'Wiki_Entity')

# %%
df_xgb_pred_result[df_xgb_pred_result['Wiki_Entity'].isin(df_50k_features['Wiki_Entity'])].shape
# Out:
# (23544, 103)

# %%
df_pred_comb.to_excel('Datasets/Tech_Classifier_Prediction_on_50k.xlsx', index = False)

# %%
df_pred_comb = pd.read_excel('Datasets/Tech_Classifier_Prediction_on_50k.xlsx')

# %%
df_pred_comb[(df_pred_comb['Wiki_Entity'].isin(trend_list)) & (df_pred_comb['Predicted_Label'] == 0)]
# Out:
#                                      Wiki_Entity  Predicted_Label  \
# 62                             Egocentric vision                0
# 1206                          Echo state network                0
# 3732                   Post-quantum cryptography                0
# 11602                                  Phenomics                0
# 14567  Cognitive behavioral therapy for insomnia                0
#
#        Predicted_Prob       ET3 meta-clusters    ET7 theme clusters  \
# 62           0.488936  Human-computer Systems          ConvergeTech
# 1206         0.114491            Data Systems     Data technologies
# 3732         0.427798            Data Systems  Network technologies
# 11602        0.318372  Human-computer Systems       Biotechnologies
# 14567        0.424193  Human-computer Systems            Healthtech
#
#        Pageviews_2019  Pageviews_2020  Pageviews_2021  Pageviews_2022  \
# 62             6235.0          6541.0          4855.0          5639.0
# ...

# %%
df_pred_comb[(df_pred_comb['Wiki_Entity'].isin(trend_list)) & (df_pred_comb['Predicted_Label'] == 0)]['Wiki_Entity'].tolist()
# Out:
# ['Egocentric vision',
#  'Echo state network',
#  'Post-quantum cryptography',
#  'Phenomics',
#  'Cognitive behavioral therapy for insomnia']

# %%
trend_list = ['Microbial electrosynthesis', 'Phenomics', 'Continuous glucose monitor', 'Unconventional computing', 
              'Optical neural network', 'Egocentric vision', 'Electronic data capture', 
              'Cognitive behavioral therapy for insomnia', 'Enterprise master patient index', 
              'Electronic navigational chart', 'GNSS reflectometry', 'Snapshot hyperspectral imaging', 
              'Quantum sensor', 'Superconducting quantum computing', 'Photonic integrated circuit', 
              'Network emulation', 'Post-quantum cryptography', 'Real-time communication', 'Multi-agent system', 
              'Generative model', 'Echo state network']

# %%
df_xgb_model_result.mean()
# Out:
# seed           366823.466667
# Accuracy            0.856429
# F1_Score            0.856373
# FBeta_Score         0.856958
# AUC_Score           0.936989
# dtype: float64

# %%
# import pickle
# filename = 'Tech_Classifier_Model.sav'
# # load the model from disk
# loaded_model = pickle.load(open(filename, 'rb'))
